# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Imports
import numpy as np   
import pandas as pd   
import os 
import tensorflow as tf 
from keras.preprocessing.sequence import pad_sequences 
from keras.preprocessing.text import Tokenizer 
from keras.models import Model 
from keras.layers import Flatten, Dense, LSTM, Dropout, Embedding, Activation 
from keras.layers import concatenate, BatchNormalization, Input
from keras.layers.merge import add 
from keras.utils import to_categorical, plot_model 
from keras.applications.inception_v3 import InceptionV3, preprocess_input 
import matplotlib.pyplot as plt
import string
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# **Load image descriptions for each image**

# %%
def load_description(text): 
    mapping = dict() 
    for line in text.split("\n"): 
        token = line.split("\t") 
        if len(line) < 2:   # remove very short descriptions 
            continue
        img_id = token[0].split('.')[0] # name of the image 
        img_des = token[1]              # description of the image 
        if img_id not in mapping: 
            mapping[img_id] = list() 
        mapping[img_id].append(img_des) 
    return mapping 
  
token_path = '/content/drive/MyDrive/Flickr_Data/Flickr_TextData/Flickr8k.token.txt'
text = open(token_path, 'r', encoding = 'utf-8').read() 
descriptions = load_description(text) 
print(descriptions['1007129816_e794419615'])
# Out:
# ['A man in an orange hat starring at something .', 'A man wears an orange hat and glasses .', 'A man with gauges and glasses is wearing a Blitz hat .', 'A man with glasses is wearing a beer can crocheted hat .', 'The man with pierced ears is wearing glasses and an orange hat .']

# %% [markdown]
# **Data Preprocessing**

# %%
#Remove punctuations and single letters
def clean_description(desc): 
    # stop_words = set(stopwords.words('english'))
    for key, des_list in desc.items(): 
        for i in range(len(des_list)): 
            caption = des_list[i] 
            caption = [ch for ch in caption if ch not in string.punctuation] 
            caption = ''.join(caption) 
            caption = caption.split(' ') 
            caption = [word.lower() for word in caption if len(word)>1 and word.isalpha()] 
            caption = ' '.join(caption)
            #Removing stop words taking lot of time - Maybe try with GPU later
            # caption = word_tokenize(caption)
            # caption = [word for word in caption if not word in stopwords.words()]
            # caption = (" ").join(caption)
            des_list[i] = caption 
  
clean_description(descriptions) 
descriptions['1000268201_693b08cb0e']
# Out:
# ['child in pink dress is climbing up set of stairs in an entry way',
#  'girl going into wooden building',
#  'little girl climbing into wooden playhouse',
#  'little girl climbing the stairs to her playhouse',
#  'little girl in pink dress going into wooden cabin']

# %% [markdown]
# **Generate text vocabulary**

# %%
#Text vocabulary
def to_vocab(desc): 
    words = set() 
    for key in desc.keys(): 
        for line in desc[key]: 
            words.update(line.split()) 
    return words 
vocab = to_vocab(descriptions)
print(vocab)
print(len(vocab))
# Out:
# {'contorts', 'guests', 'ghostbuster', 'schoolboy', 'halfcompleted', 'jean', 'overlooked', 'finds', 'tomatos', 'ponchos', 'kiyaking', 'partially', 'officiallooking', 'backback', 'sailing', 'forest', 'giants', 'snowstorm', 'cleared', 'mysterious', 'sailboat', 'cellphone', 'cringes', 'banks', 'rips', 'helped', 'guitar', 'excited', 'flatbed', 'bouncey', 'railroad', 'windowsill', 'accents', 'vertical', 'highchair', 'returns', 'lush', 'surf', 'otherwise', 'heels', 'mules', 'vfw', 'drawing', 'belts', 'raising', 'rough', 'sponsored', 'eggs', 'competitive', 'counters', 'videos', 'filling', 'garb', 'fails', 'ropes', 'dodgeball', 'dge', 'source', 'house', 'sleeveless', 'setting', 'rubble', 'whipping', 'drapped', 'amoung', 'completely', 'combat', 'anciet', 'coast', 'lighterskinned', 'tumble', 'ethnic', 'goldencolored', 'caches', 'knuckle', 'coliding', 'subject', 'lambs', 'character', 'border', 'scottish', 'read', 'motorcycles', 'peaks', 'root', 'upperclass', 'forearms', 'session', 'hatchback', 'torch', 'bohemian', 'her', 'magizine', 'tripped', 'apportioned', 'pencil', 'frisbee', 'camel', 'playstation', 'ibeam', 'cases', 'recorder', 'woodlands', 'first', 'diverse', 'stack', 'bluetinted', 'tights', 'exercised', 'dark', 'pearl', 'casual', 'trek', 'done', 'downpour', 'bouncer', 'bus', 'striding', 'twilight', 'walk', 'client', 'pants', 'racing', 'spreading', 'protester', 'obscene', 'bend', 'umbrellas', 'interestingly', 'cot', 'miscellaneous', 'are', 'cloths', 'crow', 'versus', 'refreshment', 'bluejeans', 'romantically', 'piles', 'vapour', 'soars', 'chalkboard', 'poorly', 'lined', 'tabloid', 'pit', 'stool', 'classical', 'link', 'poofy', 'tug', 'video', 'terrace', 'gated', 'prisoner', 'visits', 'navigates', 'snowpile', 'rockclimber', 'slab', 'plugging', 'needle', 'roots', 'watery', 'jet', 'panes', 'paddles', 'varying', 'steel', 'cds', 'towrope', 'york', 'shorter', 'grassy', 'venture', 'medatative', 'greyishbrown', 'tanned', 'windboard', 'sprayed', 'word', 'penzance', 'workout', 'again', 'satchel', 'gettin', 'afghan', 'additional', 'dune', 'speech', 'critter', 'certificate', 'rafters', 'dalmatian', 'families', 'prizes', 'cheap', 'letters', 'taxi', 'coasts', 'allowing', 'headphones', 'hiking', 'horseback', 'auto', 'anklehigh', 'antics', 'howls', 'thie', 'supplies', 'without', 'together', 'talent', 'recoils', 'shadowy', 'redhead', 'wrecked', 'basement', 'about', 'hr', 'redbull', 'breasts', 'aims', 'gesturing', 'help', 'bearers', 'socks', 'saris', 'convienience', 'circle', 'seeds', 'coping', 'dancing', 'unsual', 'frightened', 'art', 'paws', 'travelling', 'custom', 'barbed', 'skimply', 'recoiling', 'warming', 'snowy', 'skating', 'punkish', 'barrior', 'words', 'spread', 'pouting', 'box', 'repelling', 'challenges', 'blindfolded', 'youth', 'camera', 'liquid', 'japanesesponsored', 'looming', 'encripted', 'labelled', 'with', 'lesh', 'probably', 'tight', 'defensive', 'buff', 'squeezed', 'cashier', 'tub', 'banners', 'hug', 'meet', 'contestants', 'ravine', 'balanced', 'flops', 'downwards', 'snowball', 'vampire', 'developing', 'tiles', 'soaker', 'shawl', 'tackles', 'double', 'recreation', 'overlooking', 'dropped', 'antoher', 'woooden', 'multiple', 'wrestled', 'crate', 'napping', 'tank', 'suv', 'tatoos', 'whitehaired', 'biting', 'strap', 'rope', 'grounded', 'mouth', 'claps', 'puffy', 'terrior', 'ok', 'smoking', 'clothing', 'driving', 'squirrel', 'touched', 'customers', 'mouthpiece', 'type', 'east', 'tracks', 'picks', 'ripping', 'torwards', 'pigtails', 'sister', 'leafy', 'baptized', 'resembling', 'binocular', 'footrace', 'playground', 'army', 'streetway', 'jackolantern', 'fortune', 'parachutist', 'bare', 'seaguls', 'numerous', 'exit', 'foreigners', 'choice', 'steeple', 'mature', 'stone', 'candle', 'stange', 'crumb', 'shoeshine', 'lookout', 'panasonic', 'mocks', 'brownish', 'papers', 'fishers', 'portfolio', 'practice', 'lining', 'slaloms', 'bigbox', 'spout', 'dragons', 'steamy', 'neckdeep', 'earflaps', 'trails', 'sidwalk', 'concentrates', 'diver', 'underhang', ' ...
# 8763

# %% [markdown]
# **Load the images**

# %%
import glob 
images = '/content/drive/MyDrive/Flickr_Data/Images/'
# Create a list of all image names in the directory 
img = glob.glob(images + '*.jpg') 
  
train_path = '/content/drive/MyDrive/Flickr_Data/Flickr_TextData/Flickr_8k.trainImages.txt'
train_images = open(train_path, 'r', encoding = 'utf-8').read().split("\n") 
train_img = []  # list of all images in training set 
for im in img: 
    if(im[len(images):] in train_images): 
        train_img.append(im) 
          
# load descriptions of training set in a dictionary. Name of the image will act as key 
def load_clean_descriptions(des, dataset): 
    dataset_des = dict() 
    for key, des_list in des.items(): 
        if key+'.jpg' in dataset: 
            if key not in dataset_des: 
                dataset_des[key] = list() 
            for line in des_list: 
                #To identify the start and end of a descrition.
                desc = 'startofline ' + line + ' endofline'
                dataset_des[key].append(desc) 
    return dataset_des 
  
train_descriptions = load_clean_descriptions(descriptions, train_images) 
print(train_descriptions['1000268201_693b08cb0e'])
# Out:
# ['startofline child in pink dress is climbing up set of stairs in an entry way endofline', 'startofline girl going into wooden building endofline', 'startofline little girl climbing into wooden playhouse endofline', 'startofline little girl climbing the stairs to her playhouse endofline', 'startofline little girl in pink dress going into wooden cabin endofline']

# %% [markdown]
# **Extract Features from Images**

# %%
from keras.preprocessing.image import load_img, img_to_array 
def preprocess_img(img_path): 
    # inception v3 needs img in 299 * 299 * 3 - https://keras.io/api/applications/inceptionv3/
    img = load_img(img_path, target_size = (299, 299)) 
    x = img_to_array(img) 
    # Add one more dimension - preprocess_inputs(x) fails without it
    x = np.expand_dims(x, axis = 0) 
    x = preprocess_input(x) 
    return x 
  
def encode(image): 
    image = preprocess_img(image) 
    vec = model.predict(image) 
    vec = np.reshape(vec, (vec.shape[1])) 
    return vec 
  
base_model = InceptionV3(weights = 'imagenet') 
model = Model(base_model.input, base_model.layers[-2].output) #Last classification layer removed for output to get the feature vectors from the model
# run the encode function on all train images and store the feature vectors in a list 
encoding_train = {} 
for img in train_img: 
    encoding_train[img[len(images):]] = encode(img)

print(encoding_train)
# Out:
# Streaming output truncated to the last 5000 lines.
#        0.26973796], dtype=float32), '3568065409_1c381aa854.jpg': array([0.08721863, 0.38708878, 0.19927518, ..., 0.29555747, 0.0735969 ,
#        0.39816463], dtype=float32), '3564436847_57825db87d.jpg': array([0.06878709, 0.07074788, 0.12302593, ..., 0.16695021, 0.09807597,
#        0.09038803], dtype=float32), '3576060775_d9121519cc.jpg': array([0.7259877 , 0.37332207, 0.4155422 , ..., 0.03974202, 0.7123362 ,
#        0.7669268 ], dtype=float32), '3568605391_54ec367d88.jpg': array([0.19067006, 0.18852156, 0.34742355, ..., 0.4841697 , 0.26390535,
#        0.21527898], dtype=float32), '3595216998_0a19efebd0.jpg': array([0.16574255, 0.38895166, 0.03799228, ..., 0.8551868 , 0.01280369,
#        0.14024502], dtype=float32), '3581818450_546c89ca38.jpg': array([0.31646192, 0.47425446, 0.03358114, ..., 0.53632337, 0.32040995,
#        0.38701442], dtype=float32), '3598447435_f66cd10bd6.jpg': array([0.18375964, 0.11183792, 0.02978899, ..., 0.8669895 , 0.8061775 ,
#        0.79122865], dtype=float32), '3589368949_0866846949.jpg': array([0.3819601 , 0.24580988, 0.74008095, ..., 0.31569237, 0.93662524,
#        0.13089433], dtype=float32), '3593222804_c187808ac3.jpg': array([0.02654276, 0.3508291 , 0.22467151, ..., 0.97959757, 1.2452226 ,
#        0.05689918], dtype=float32), '3600909823_ce72c26e66.jpg': array([0.21839944, 0.50789964, 0.03684505, ..., 0.22117087, 1.0202279 ,
#        0.11375956], dtype=float32), '3583704941_611353857e.jpg': array([0.14021692, 0.20483963, 0.10636879, ..., 0.39132914, 0.20882839,
#        0.08601296], dtype=float32), '3582914739_bef2828a06.jpg': array([0.04471703, 0.31502467, 0.14872798, ..., 0.29300267, 0.44969857,
#        0.42673087], dtype=float32), '3568505408_4e30def669.jpg': array([0.12094643, 0.558557  , 0.5105932 , ..., 0.9286729 , 0.52138233,
#        0.32368946], dtype=float32), '3591094476_b61acd63d6.jpg': array([0.47648585, 0.19921145, 0.6283724 , ..., 0.64492494, 0.14524606,
#        0.05683513], dtype=float32), '3578981202_efef47e264.jpg': array([0.5228579 , 0.33952093, 0.24667892, ..., 0.16818193, 0.33476478,
#        0.32647076], dtype=float32), '3576840040_9356b5b10a.jpg': array([0.1394763 , 0.3515595 , 0.05177962, ..., 0.31156898, 0.21697879,
#        0.08859047], dtype=float32), '357191373_a1cb5696e8.jpg': array([0.09621754, 0.1618002 , 0.83049154, ..., 0.31739324, 0.20759569,
#        0.18259403], dtype=float32), '3595080592_5fd55570e5.jpg': array([0.8435619 , 0.4785995 , 0.39359736, ..., 0.04946249, 0.38560975,
#        0.31663114], dtype=float32), '3569667295_6e51db08ef.jpg': array([0.15092266, 0.04305084, 0.11821339, ..., 0.0524662 , 0.79697704,
#        0.06488736], dtype=float32), '3565021218_d2bc1aa644.jpg': array([0.25709718, 0.58654654, 1.1958086 , ..., 0.8584386 , 0.8745849 ,
#        0.27487537], dtype=float32), '3565655045_8eb00b7423.jpg': array([0.3477766 , 0.08328649, 0.21286732, ..., 0.15179247, 0.21501186,
#        0.24759969], dtype=float32), '3573436368_78f0ccdf01.jpg': array([0.39053613, 0.37917215, 0.14323294, ..., 0.06451865, 0.35148358,
#        0.00182625], dtype=float32), '3597921737_3fd1d0665b.jpg': array([0.6693958 , 0.7789645 , 1.3238968 , ..., 0.69385755, 1.0088743 ,
#        0.24968731], dtype=float32), '3594822096_e1144b85d6.jpg': array([0.2306353 , 0.28601184, 0.04723004, ..., 0.477472  , 0.66337204,
#        0.46949953], dtype=float32), '3577235421_69e4efb8d1.jpg': array([0.19952662, 0.21681574, 0.28359446, ..., 0.8994953 , 0.610271  ,
#        0.2788251 ], dtype=float32), '3613667665_1881c689ea.jpg': array([0.27546024, 0.25999385, 0.0805271 , ..., 0.15447766, 1.02841   ,
#        0.686293  ], dtype=float32), '3604384383_db6805d1b9.jpg': array([0.35386556, 0.29771003, 0.42302465, ..., 1.7023578 , 1.2019529 ,
#        0.500364  ], dtype=float32), '3613005134_bb7f304da1.jpg': array([0.71973187, 0.31092134, 0.68403447, ..., 1.0271618 , 0.440573  ,
#        0.2931941 ], dtype=float32), '3626642428_3396568c3c.jpg': array([0.23950948, 0.20049588, 0.21178758, ..., 0.22116238, 0.49893245,
#        0.1535629 ], dtype=float32), '3627676364_1dc9294ec5.jpg': array([0.8282018 , 0.34367144, 0.69521844, ..., 0.7632847 , 0.37639314,
#        0.24393345], dtype=float32), '3628698119_5566769777.jpg': array([0.37926453, 0.11570265, 0.21218482, ..., 0.28709787, 0.25589406,
#        0.04243068], dtype=float32), '3606355203_1260f43ec0.jpg': array([0.54258174, 0.33946294, 0.34255576, ..., 1.0393621 , 1.0357605 ,
#        0.7785216 ], dtype=float32), '3621649810_cca783b777.jpg': array([0.9083253 , 0.1699706 , 0.63731205, ..., 0.5384787 , 1.3864195 ,
#        0.1333651 ], dtype=float32), '3621652774_fd9634bd5b.jpg': array([0.42615223, 0.16211444, 0.15030771, ..., 0.4935837 , 1.8082414 ,
#        0.99951774], dtype=float32), '3613264553_97b687f172.jpg': array([0.07392049, 0.15381883, 0.1929572 , ..., 0.2945723 , 0.55995345,
#        0.2878608 ], dtype=float32), '3603870481_1ebc696d91.jpg': array([0.06549413, 0.1778838 , 0.25654608, ..., 0.14676747, 0.69713193,
#        0.05073572], dtype=float32), '3613323772_d15cef66d1.jpg': array([0.03916235, 0.20340443, 0.10231862, ..., 0.45535272, 0.13296372,
#        0.31423196], dtype=float32), '3614582606_16bd88dab2.jpg': array([0.36758703, 0.92551744, 1.5606165 , ..., 0.5309095 , 0.54325163,
#        0.22875491], dtype=float32), '3622216490_1314a58b66.jpg': array([0.15408266, 0.2605569 , 0.3197251 , ..., 0.85220706, 0.10174862,
#        0.10191533], dtype=float32), '3613375729_d0b3c41556.jpg': array([0.10917956, 0.439475  , 0.05825198, ..., 0.32902923, 0.27479145,
#        0.14322218], dtype=float32), '3636247381_65ccf8f106.jpg': array([0.113895  , 0.30139852, 0.19585505, ..., 0.18756178, 0.52236736,
#        0.31520778], dtype=float32), '3615239961_62b4dbc174.jpg': array([0.10807684, 0.7206328 , 0.7139791 , ..., 0.14030434, 0.6760924 ,
#        0.08518407], dtype=float32), '3602676311_824b2c04ba.jpg': array([0.09897074, 0.19735152, 0.06325193, ..., 0.07508102, 0.06084638,
#        0.94746965], dtype=float32), '3614542901_29877fc342.jpg': array([0.97349143, 0.7435857 , 2.5119586 , ..., 0.20722201, 1.4440453 ,
#        0.01408406], dtype=float32), '3626964430_cb5c7e5acc.jpg': array([0.50944316, 0.4767719 , 1.0724652 , ..., 0.18121012, 0.11605233,
#        0.32028657], dtype=float32), '3616638478_641d02183d.jpg': array([0.56802595, 0.5711168 , 0.35461992, ..., 0.39866862, 1.3756447 ,
#        0.31259018], dtype=float32), '3636055584_65a60426f8.jpg': array([0.3771742 , 0.20079976, 0.25390756, ..., 0.03342146, 0.21506834,
#        0.22420132], dtype=float32), '3635911776_dbc2763f2c.jpg': array([0.25090665, 0.22420865, 0.5443814 , ..., 0.45161366, 0.7875565 ,
#        0.35520136], dtype=float32), '3628017876_4ac27e687b.jpg': array([0.05602759, 0.27235627, 0.05883302, ..., 0.5799329 , 0.18181476,
#        0.20225324], dtype=float32), '3606846822_28c40b933a.jpg': array([0.08386673, 0.47911286, 0.19749604, ..., 1.4657787 , 0.1948146 ,
#        0.86843324], dtype=float32), '3606942887_1159d92548.jpg': array([0.5469248 , 0.11428113, 0.34580576, ..., 0.42864335, 0.8165562 ,
#        1.0759107 ], dtype=float32), '3632225464_612d7b4c0f.jpg': array([0.1966488 , 0.02817062, 0.10628748, ..., 1.2615001 , 0.20444176,
#        0.4502571 ], dtype=float32), '3619806638_7480883039.jpg': array([0.7689705 , 0.22955124, 0.9781954 , ..., 0.25710377, 1.2167287 ,
#        0.36970723], dtype=float32), '3634032601_2236676cdd.jpg': array([1.1370081 , 0.37148583, 0.7574343 , ..., 0.14097235, 0.46420944,
#        0.10181689], dtype=float32), '3634400263_c6fcaa48e1.jpg': array([0.31996182, 0.30321652, 0.18078431, ..., 0.5573358 , 0.47007397,
#        0.59987205], dtype=float32), '3632047678_f202609e50.jpg': array([0.24628365, 0.15258227, 0.45753035, ..., 0.        , 0.19784845,
#        0.09683745], dtype=float32), '3632258003_6a0a69bf3a.jpg': array([0.29136106, 0.26671433, 0.25421336, ..., 0.26045263, 0.67952025,
#        0.6415973 ], dtype=float32), '3636543173_15f56515e5.jpg': array([0.7058282 , 0.97906554, 0.54565334, ..., 0.13599412, 0.61647516,
#        0.05517506], dtype=float32), '3638178504_be1ff246bd.jpg': array([0.23146823, 0.5312722 , 0.14297815, ..., 0.1609265 , 0.36664647,
#        0.10118563], dtype=float32), '3631344685_ed0f3e091b.jpg': array([0.12561049, 0.17239693, 0.14483704, ..., 0.2939957 , 0.31027472,
#        0.198149  ], dtype=float32), '3638459638_ec74e3ff89.jpg': array([0.13736862, 0.01361587, 0.07476296, ..., 0.07074921, 0.44515926,
#        0.0821801 ], dtype=float32), '3604384157_99241be16e.jpg': array([0.16284725, 0.08460397, 0.5298962 , ..., 0.43301508, 0.5093527 ,
#        0.03005109], dtype=float32), '3608400551_d6f7965308.jpg': array([0.54479885, 1.3158243 , 0.46023673, ..., 0.03093177, 1.0562003 ,
#        0.352235  ], dtype=float32), '3613705104_46d854134e.jpg': array([0.7512231 , 0.17138046, 0.4304526 , ..., 0.2759361 , 0.35683212,
#        0.3730389 ], dtype=float32), '3606084228_6286a52875.jpg': array([0.08860439, 0.74555266, 0.02893694, ..., 0.13881446, 0.2612936 ,
#        0.4695385 ], dtype=float32), '3628043835_9d9bd595a7.jpg': array([0.23396823, 0.2858979 , 0.31186768, ..., 0.01361763, 0.84222436,
#        0.17348926], dtype=float32), '3632572264_577703b384.jpg': array([0.33992517, 0.3985721 , 0.7550123 , ..., 0.13350418, 0.28587505,
#        0.58013296], dtype=float32), '3621177753_1718c30ea0.jpg': array([0.37660992, 0.14214812, 0.13284954, ..., 0.01605978, 0.10085905,
#        0.2965786 ], dtype=float32), '3638631362_af29bbff01.jpg': array([0.13635954, 0.34547144, 0.3482869 , ..., 0.7073832 , 0.4321744 ,
#        0.33013904], dtype=float32), '3613030730_0b28b079ba.jpg': array([0.23775326, 0.4388129 , 0.16389178, ..., 0.7776571 , 0.46731278,
#        0.155667  ], dtype=float32), '3627679667_0e3de9fc90.jpg': array([0.3168313 , 0.03817932, 0.6560112 , ..., 0.03925382, 0.7425161 ,
#        0.18467101], dtype=float32), '3627216820_4952bacbcb.jpg': array([0.54385066, 1.3489821 , 0.20836842, ..., 0.10610403, 0.86232185,
#        1.049516  ], dtype=float32), '3623331945_df0f51d7dd.jpg': array([0.166574  , 0.03898585, 0.4977002 , ..., 0.0147107 , 1.0646608 ,
#        0.05342253], dtype=float32), '3629664676_36bcefe6b7.jpg': array([0.52351296, 0.7648246 , 0.1597344 , ..., 0.15033793, 0.5024347 ,
#        0.56632894], dtype=float32), '3606909929_90a1a072b7.jpg': array([0.2801138 , 0.21003504, 0.08570319, ..., 0.11601397, 0.22940433,
#        0.4121589 ], dtype=float32), '3606093421_eddd46c2c7.jpg': array([0.24241981, 0.24326259, 0.14296195, ..., 0.25500304, 0.09925056,
#        1.1096315 ], dtype=float32), '3626475209_f71cdd06bd.jpg': array([0.24370348, 0.6892859 , 0.52784497, ..., 0.43163347, 0.40673277,
#        0.49413344], dtype=float32), '3609999845_faf5d2fe74.jpg': array([0.37410533, 0.7548013 , 0.5991602 , ..., 0.9684259 , 0.13651577,
#        0.        ], dtype=float32), '3603116579_4a28a932e2.jpg': array([0.06152864, 0.00814837, 0.11293427, ..., 0.19006673, 0.05508453,
#        0.12515134], dtype=float32), '3611672054_45edd3e08f.jpg': array([0.16584298, 0.05249487, 0.25059742, ..., 0.0739189 , 0.40062183,
#        0.27407247], dtype=float32), '3604314527_5077cd9d43.jpg': array([0.1696249 , 0.29371756, 0.24814066, ..., 0.11157829, 0.25725153,
#        0.10718243], dtype=float32), '361092202_3d70144ebd.jpg': array([0.33639276, 0.5667794 , 0.5678983 , ..., 0.25706902, 0.4168285 ,
#        0.5732983 ], dtype=float32), '3628994466_a12065d29b.jpg': array([0.0537493 , 0.15914589, 0.6595224 , ..., 0.5569141 , 0.04312629,
#        0.5726327 ], dtype=float32), '3618932839_acd7d2c2ea.jpg': array([0.30070513, 0.29132026, 0.49585962, ..., 0.35262477, 0.9314432 ,
#        0.30457515], dtype=float32), '3620343911_64a862904e.jpg': array([0.28844252, 0.08203344, 0.66530025, ..., 0.33067173, 1.1278524 ,
#        0.32552576], dtype=float32), '3626689571_5817f99c0e.jpg': array([0.28385836, 0.28784966, 0.40500194, ..., 0.04537919, 0.22635877,
#        1.0032068 ], dtype=float32), '3619381206_5bc8b406f9.jpg': array([0.12122963, 0.57947993, 0.2829299 , ..., 0.28217936, 0.15126236,
#        0.35322398], dtype=float32), '3631671718_d712821757.jpg': array([0.15227641, 0.9307365 , 0.19596967, ..., 0.48316097, 0.08296038,
#        0.25261286], dtype=float32), '3605100550_01214a1224.jpg': array([0.56411695, 1.1157018 , 0.14368862, ..., 0.2740907 , 1.5140172 ,
#        1.1121023 ], dtype=float32), '3610836023_3a972b10b0.jpg': array([0.06000657, 0.32674253, 0.03826727, ..., 0.08216248, 0.00471745,
#        0.04331646], dtype=float32), '3616525288_9c19223de6.jpg': array([0.03292162, 0.19359261, 0.33064166, ..., 0.43913993, 0.32631755,
#        1.1821445 ], dtype=float32), '3629492654_619d7b67ee.jpg': array([0.24121842, 0.49841034, 0.26686275, ..., 0.5638451 , 0.21034731,
#        0.53381145], dtype=float32), '3634785801_4b23184a06.jpg': array([0.46049747, 0.23968893, 0.32280225, ..., 0.16677004, 0.5818624 ,
#        0.79765636], dtype=float32), '3607405494_0df89110a6.jpg': array([4.1493779e-01, 2.6978821e-01, 7.5135507e-02, ..., 4.9485636e-01,
#        2.2783270e-04, 3.1254008e-01], dtype=float32), '362316425_bda238b4de.jpg': array([0.26431012, 1.134935  , 1.2404894 , ..., 0.94280076, 1.5066993 ,
#        0.01429073], dtype=float32), '3613242966_a1c63a0174.jpg': array([0.09810424, 0.03459915, 0.3424905 , ..., 0.28120548, 0.30734697,
#        0.06539927], dtype=float32), '3604391853_b4809fcb8c.jpg': array([0.34551513, 0.21263972, 0.21261099, ..., 1.4541076 , 0.08891612,
#        0.06334345], dtype=float32), '3612484827_0e479f9ee8.jpg': array([0.13136235, 0.26012322, 0.17593348, ..., 0.17413184, 0.5614171 ,
#        0.3117801 ], dtype=float32), '3612825666_54f5a2bc06.jpg': array([0.69193596, 0.17327012, 0.55605584, ..., 0.10538118, 0.05883605,
#        0.07474674], dtype=float32), '3634828052_3b6aeda7d6.jpg': array([0.36080045, 0.23107809, 0.588038  , ..., 0.02743305, 1.1270359 ,
#        0.31686813], dtype=float32), '3616771728_2c16bf8d85.jpg': array([0.01675541, 0.18587542, 0.24360804, ..., 0.7439519 , 0.54212594,
#        0.2613417 ], dtype=float32), '3607489370_92683861f7.jpg': array([0.19749829, 0.9307251 , 0.1250953 , ..., 0.18376479, 0.5342544 ,
#        0.3746436 ], dtype=float32), '3604383863_5e387cb8e6.jpg': array([0.2162152 , 0.24905375, 0.33479565, ..., 0.68253934, 0.47456712,
#        0.11164829], dtype=float32), '3634281981_d9cf1d1a33.jpg': array([0.06250469, 0.37922975, 0.27961794, ..., 0.19577658, 0.8894757 ,
#        0.15326515], dtype=float32), '3631474374_e40764d153.jpg': array([0.7501338 , 0.99877274, 0.71998775, ..., 0.48918125, 0.9909405 ,
#        0.32653707], dtype=float32), '3631136463_53ff624b82.jpg': array([4.0181023e-01, 2.5485250e-01, 9.5556438e-02, ..., 2.2735929e-01,
#        0.0000000e+00, 2.6647045e-04], dtype=float32), '3609952704_3719ab0524.jpg': array([0.43854052, 0.2613328 , 0.41375688, ..., 0.35184503, 0.4639016 ,
#        0.17318627], dtype=float32), '361183669_52be9662b9.jpg': array([0.35416383, 0.46226692, 0.49268264, ..., 0.68213844, 0.5775376 ,
#        0.5193039 ], dtype=float32), '3621623690_0095e330bc.jpg': array([0.14237699, 0.7092988 , 0.31702262, ..., 0.52387655, 0.95461947,
#        0.21108136], dtype=float32), '3612485611_12dd7742f7.jpg': array([0.31105304, 0.26542705, 0.6972862 , ..., 0.28389502, 0.00492011,
#        0.79820764], dtype=float32), '3618908551_7fd2de5710.jpg': array([0.6839343 , 0.3305146 , 0.21882169, ..., 0.3688144 , 0.11704646,
#        1.6481969 ], dtype=float32), '3607969989_68cc411493.jpg': array([0.11146376, 0.01076012, 0.7504051 , ..., 0.4057439 , 0.01235736,
#        0.66395336], dtype=float32), '3627290893_561e176e80.jpg': array([0.5613575 , 0.25150886, 0.744967  , ..., 0.82169384, 0.08775766,
#        0.14719012], dtype=float32), '3614595423_f9e0ab4fb0.jpg': array([1.067561  , 1.0226648 , 1.3859801 , ..., 1.417342  , 1.5678964 ,
#        0.00760619], dtype=float32), '3608849440_e7d2bed29f.jpg': array([0.33310574, 0.28641954, 0.56299925, ..., 0.23235671, 0.19148786,
#        0.5807655 ], dtype=float32), '3638374272_444f5e0457.jpg': array([0.7863572 , 0.19667795, 0.65080523, ..., 0.28047216, 0.12953152,
#        0.15904361], dtype=float32), '3614881872_ccf9739b0e.jpg': array([0.08708847, 0.60087717, 0.16075575, ..., 0.6514108 , 0.7318714 ,
#        0.8919113 ], dtype=float32), '3627076769_3b71e73018.jpg': array([0.45914188, 0.2527238 , 0.21275964, ..., 0.64739007, 0.20990413,
#        0.15482315], dtype=float32), '3636418958_f038130bb2.jpg': array([0.7747074 , 0.3366675 , 0.22373775, ..., 0.1986242 , 0.10311066,
#        0.7632045 ], dtype=float32), '3626998066_3ae11ee278.jpg': array([0.8685185 , 0.27481124, 0.08359773, ..., 0.1114939 , 0.15803671,
#        0.67242587], dtype=float32), '3603064161_a8f3b6455d.jpg': array([0.1868083 , 0.18589196, 0.12094913, ..., 0.6511136 , 0.20110932,
#        0.00896785], dtype=float32), '3637966641_1b108a35ba.jpg': array([0.38963974, 0.18534333, 0.7484212 , ..., 0.05377996, 0.02716511,
#        0.53872764], dtype=float32), '3632842482_482f29e712.jpg': array([0.56784475, 0.13515553, 0.16090733, ..., 0.11554605, 0.51902986,
#        0.7117506 ], dtype=float32), '3636491114_ab34dac833.jpg': array([0.31300396, 0.13220145, 0.35163867, ..., 0.20903397, 0.96115017,
#        0.4149768 ], dtype=float32), '3635194562_4c1dfa120a.jpg': array([0.44942722, 0.43256584, 0.6338929 , ..., 0.20236163, 0.50260925,
#        1.1431358 ], dtype=float32), '360723732_23199af4bf.jpg': array([0.3260863 , 0.26419157, 0.20134597, ..., 0.33043134, 0.74329734,
#        0.18420969], dtype=float32), '3636796219_9916c0465a.jpg': array([0.14866276, 0.09739278, 0.22215062, ..., 0.09754691, 0.02232823,
#        0.36505264], dtype=float32), '3613585080_36629d8157.jpg': array([0.6121657 , 0.4785028 , 0.81623244, ..., 0.45773494, 0.68996906,
#        0.78356785], dtype=float32), '3610687607_895fdc94bd.jpg': array([0.27966756, 0.45846236, 0.5415115 , ..., 0.23715857, 0.6526387 ,
#        0.0907068 ], dtype=float32), '3636126441_5617c89aaa.jpg': array([0.19987404, 0.58521247, 0.13758445, ..., 0.4379804 , 0.30762845,
#        0.09866217], dtype=float32), '3628103548_2708abcda2.jpg': array([0.5133358 , 0.23755898, 0.53827983, ..., 1.1797085 , 0.16978005,
#        0.09827331], dtype=float32), '3638318149_b60450bfbe.jpg': array([0.53838456, 0.20997971, 0.32762238, ..., 0.3304906 , 0.42371112,
#        0.57856286], dtype=float32), '3624076529_9793655a21.jpg': array([0.2846973 , 0.2981274 , 0.10819247, ..., 0.06749274, 0.19413018,
#        0.10424833], dtype=float32), '3610189629_f46de92ab3.jpg': array([0.33838004, 0.42632663, 0.3137423 , ..., 0.5157517 , 1.0156391 ,
#        1.4561813 ], dtype=float32), '3609027309_af75f773d9.jpg': array([0.22013637, 0.25008202, 0.4537864 , ..., 0.07459578, 0.32109848,
#        0.42156404], dtype=float32), '3635177305_bfbe1fc348.jpg': array([0.7150402 , 0.4442828 , 0.19140626, ..., 0.19867332, 0.1438309 ,
#        0.31453383], dtype=float32), '3612249030_e2829ffa31.jpg': array([0.20959349, 0.13469228, 0.7981458 , ..., 0.8119687 , 0.4170159 ,
#        0.74789435], dtype=float32), '3620492762_7f6a9b4746.jpg': array([0.14303425, 0.45996097, 0.0722768 , ..., 0.1956822 , 0.5617559 ,
#        0.4625532 ], dtype=float32), '3636632926_09f39f2629.jpg': array([0.31541765, 0.5668764 , 0.6909064 , ..., 0.9603504 , 0.69936395,
#        0.7867306 ], dtype=float32), '3616846215_d61881b60f.jpg': array([0.36371425, 0.33066392, 0.9225    , ..., 0.41990793, 0.775223  ,
#        0.2068331 ], dtype=float32), '3612538549_2828b45867.jpg': array([0.85621804, 0.18274736, 0.2511201 , ..., 0.59797937, 0.42478508,
#        1.001914  ], dtype=float32), '3628059004_5c3529b120.jpg': array([0.6755525 , 1.0573642 , 0.8670783 , ..., 0.63685185, 0.13911724,
#        0.23691663], dtype=float32), '3621741935_54d243f25f.jpg': array([0.6221411 , 0.8071568 , 0.44735253, ..., 0.15169647, 0.60938334,
#        0.12440063], dtype=float32), '3608567609_aae96d4a5e.jpg': array([1.0697029 , 0.12728916, 0.9257525 , ..., 0.520584  , 0.04053489,
#        0.20574413], dtype=float32), '3625957413_e475943aa3.jpg': array([0.2483204 , 0.38045692, 0.07711169, ..., 0.47295815, 0.10039263,
#        0.6511363 ], dtype=float32), '3611603026_9112b0c53f.jpg': array([0.4867841 , 0.22296986, 0.5120586 , ..., 0.10237443, 0.6520442 ,
#        0.20633493], dtype=float32), '3618115051_41b5a7706c.jpg': array([0.17151113, 0.5872631 , 0.4531806 , ..., 0.22702472, 0.81052184,
#        0.5190822 ], dtype=float32), '3638577494_fe55f7b4cb.jpg': array([0.22628677, 0.5009007 , 0.42202786, ..., 0.50695056, 0.59754765,
#        0.84536934], dtype=float32), '3630102841_b4c3e00b2c.jpg': array([0.36083227, 0.6221666 , 0.09509621, ..., 0.24188885, 0.34538776,
#        0.0658165 ], dtype=float32), '3621717946_d96f8a6012.jpg': array([0.5807344 , 0.19205977, 0.6180159 , ..., 0.11589208, 0.6943813 ,
#        0.23635286], dtype=float32), '3621647714_fc67ab2617.jpg': array([0.02456352, 0.16410358, 0.18524271, ..., 0.80569863, 0.2044226 ,
#        0.49107537], dtype=float32), '3603301825_5817727be2.jpg': array([0.21845494, 0.28976208, 0.3932475 , ..., 0.16485381, 0.15374924,
#        0.42187294], dtype=float32), '3619630328_2d0865b6f4.jpg': array([0.15008552, 0.83246726, 0.40906453, ..., 0.27345526, 0.41357452,
#        0.01981797], dtype=float32), '3637013_c675de7705.jpg': array([0.2718537 , 0.2966612 , 0.5163132 , ..., 0.        , 0.0536354 ,
#        0.30918264], dtype=float32), '3615730936_23457575e9.jpg': array([0.10273305, 0.7602616 , 0.07319663, ..., 0.267412  , 1.5019915 ,
#        0.17353477], dtype=float32), '3632197966_0c5061025f.jpg': array([0.7014859 , 0.8732594 , 0.25380924, ..., 0.31603414, 0.50089973,
#        0.5047481 ], dtype=float32), '3618525295_d32d634b2e.jpg': array([0.96533173, 0.05881066, 0.45010817, ..., 0.03186677, 0.2774962 ,
#        0.31644538], dtype=float32), '3612485097_b706d950ed.jpg': array([0.23596483, 0.34183794, 0.5621507 , ..., 0.3685095 , 0.12293521,
#        0.6187959 ], dtype=float32), '3609026563_9c66f2dc41.jpg': array([0.6564671 , 0.1872993 , 0.21390505, ..., 0.42053857, 0.61916745,
#        0.7766708 ], dtype=float32), '3638440337_6d5c19a8f0.jpg': array([0.31852975, 0.11908822, 0.214402  , ..., 0.32674128, 1.6956952 ,
#        0.46387583], dtype=float32), '3613027188_1645ca1976.jpg': array([0.22209206, 0.07051607, 0.07001394, ..., 0.28303206, 0.13243103,
#        0.88748264], dtype=float32), '3625049113_554d82c2a1.jpg': array([0.11550805, 0.10363185, 0.1411696 , ..., 0.8473387 , 0.32957226,
#        0.83989143], dtype=float32), '3633396324_c4b24b1f51.jpg': array([0.44794232, 0.2978517 , 0.7004078 , ..., 1.0371847 , 0.4673245 ,
#        0.34558895], dtype=float32), '3663307538_468739e4c3.jpg': array([0.5075309 , 0.3990096 , 0.21253183, ..., 0.01606109, 0.14358109,
#        0.33451453], dtype=float32), '3654103642_075f8af4f4.jpg': array([0.28016222, 0.10998891, 0.24854264, ..., 0.5018382 , 0.36850116,
#        0.63094175], dtype=float32), '3639363462_bcdb21de29.jpg': array([0.17229809, 0.15585266, 0.38476306, ..., 0.61331743, 0.64419967,
#        0.12980288], dtype=float32), '3660826540_481d25fbb0.jpg': array([0.4749857 , 0.12311509, 0.42396685, ..., 1.6124821 , 0.12994236,
#        0.06081645], dtype=float32), '3640743904_d14eea0a0b.jpg': array([0.14650619, 0.1405769 , 0.21563262, ..., 0.15622996, 0.08313794,
#        0.3508007 ], dtype=float32), '3668518431_43abb169eb.jpg': array([0.33190167, 0.28229415, 0.5734861 , ..., 0.69106734, 0.57253826,
#        1.3589997 ], dtype=float32), '3665569615_9a71c4b6e4.jpg': array([0.30073205, 0.06936121, 0.417803  , ..., 0.44321117, 0.00298892,
#        0.10804951], dtype=float32), '3656151153_b4ed5d94c4.jpg': array([0.27382347, 0.11241128, 0.71165854, ..., 0.69402444, 0.69138634,
#        0.27271056], dtype=float32), '3673878924_506c9d767b.jpg': array([0.4164065 , 0.42427623, 0.86900926, ..., 0.204422  , 0.65682554,
#        1.0067145 ], dtype=float32), '3640348910_fcd627ec66.jpg': array([0.5961398 , 0.20028089, 0.10456552, ..., 1.0954769 , 1.1647565 ,
#        0.40665847], dtype=float32), '3652584682_5b5c43e445.jpg': array([0.42700112, 0.0707317 , 1.360682  , ..., 0.19958629, 0.7246486 ,
#        0.43426102], dtype=float32), '3662406028_29b9e46a6f.jpg': array([0.5790122 , 0.6728842 , 0.7844418 , ..., 0.0012043 , 0.19574432,
#        0.10826258], dtype=float32), '3647283075_3005333222.jpg': array([0.21161126, 0.37092584, 1.0182128 , ..., 0.35436374, 0.14492956,
#        0.533152  ], dtype=float32), '3651476768_2bae721a6b.jpg': array([0.02878866, 0.07024137, 0.24441722, ..., 0.07932299, 0.1920852 ,
#        0.53226715], dtype=float32), '3672109677_8caa992671.jpg': array([1.1363556 , 0.74413896, 0.688576  , ..., 0.68913984, 1.2890421 ,
#        0.7697432 ], dtype=float32), '3664297064_a4d45cbbbc.jpg': array([0.5419551 , 1.0293385 , 1.0539957 , ..., 0.5707468 , 1.2122257 ,
#        0.14959174], dtype=float32), '3648097366_706c8a57a1.jpg': array([0.35309833, 0.3674206 , 0.6117007 , ..., 0.81385803, 0.94817436,
#        0.84392583], dtype=float32), '3649387275_75295baa28.jpg': array([0.11161882, 1.01185   , 0.29182065, ..., 0.7568068 , 0.3365738 ,
#        0.6900108 ], dtype=float32), '3650111717_346804ec2f.jpg': array([0.07758558, 0.05026367, 0.1013083 , ..., 1.0014507 , 0.38080418,
#        0.10654936], dtype=float32), '3658733605_fbcf570843.jpg': array([0.1200043 , 0.8417374 , 0.20137869, ..., 0.18400183, 0.50425124,
#        0.27483264], dtype=float32), '3671851846_60c25269df.jpg': array([0.3981213 , 0.14932576, 0.29956526, ..., 0.32870775, 0.87295604,
#        0.14445637], dtype=float32), '3668259129_e073af1533.jpg': array([0.19957073, 0.31980485, 0.03701488, ..., 0.04993847, 0.17453991,
#        0.31094077], dtype=float32), '3640329164_20cb245fd5.jpg': array([0.41095918, 0.07199249, 0.47322917, ..., 0.09545192, 0.62597686,
#        0.4715762 ], dtype=float32), '3643684688_2f7157b23d.jpg': array([1.1630107 , 0.27552897, 0.16252318, ..., 0.05273183, 0.89743876,
#        0.02979494], dtype=float32), '3671777903_6fbf643980.jpg': array([0.2636252 , 0.2464597 , 0.29583156, ..., 0.92201185, 0.4555473 ,
#        0.22826259], dtype=float32), '3674521435_89ff681074.jpg': array([0.70869374, 0.20794943, 0.365921  , ..., 0.00789346, 0.79840887,
#        0.5996982 ], dtype=float32), '3639617775_149001232a.jpg': array([0.47753382, 0.69331014, 2.0215702 , ..., 0.08220976, 0.58539844,
#        0.1460307 ], dtype=float32), '3647170476_0fd71a4c9f.jpg': array([0.25784114, 0.38414395, 0.8804537 , ..., 0.05040024, 0.9261654 ,
#        0.02892314], dtype=float32), '3657209354_cde9bbd2c5.jpg': array([0.15791531, 0.07691371, 0.18373713, ..., 1.5016723 , 0.6321118 ,
#        0.        ], dtype=float32), '3638992163_a085cc0c24.jpg': array([0.31871176, 1.2054205 , 0.449547  , ..., 0.10606821, 0.75307417,
#        0.10508695], dtype=float32), '3644142276_caed26029e.jpg': array([0.56215966, 0.21899542, 0.47903395, ..., 0.        , 0.2242918 ,
#        0.10230014], dtype=float32), '3670918456_68631d362a.jpg': array([0.03758051, 0.03950321, 0.21400137, ..., 0.18037416, 0.        ,
#        0.05681789], dtype=float32), '3646927481_5e0af1efab.jpg': array([0.49719375, 0.4522806 , 0.20787212, ..., 0.39222145, 0.24373466,
#        0.24068122], dtype=float32), '3673035152_da7ed916d9.jpg': array([0.70831865, 0.42564422, 0.34513402, ..., 0.33704206, 0.8686769 ,
#        0.12316971], dtype=float32), '3649382413_58a4b1efe8.jpg': array([0.54351246, 0.43058163, 0.581765  , ..., 1.2107633 , 0.38345015,
#        0.6784292 ], dtype=float32), '3656206975_09e6ce58bd.jpg': array([0.21398538, 0.04458953, 0.11661945, ..., 0.03538046, 0.20590955,
#        0.09991297], dtype=float32), '3654869593_c8599a8e20.jpg': array([0.3391531 , 0.45904768, 0.50753945, ..., 0.93312514, 1.1799202 ,
#        0.13393086], dtype=float32), '3638688673_176f99d7fd.jpg': array([0.06696113, 0.02720598, 0.10198285, ..., 0.28315234, 0.        ,
#        0.02152732], dtype=float32), '3641999223_942f8198cc.jpg': array([0.41909167, 0.19662148, 0.24012761, ..., 0.09248964, 0.2779426 ,
#        0.15894508], dtype=float32), '3641456303_c50c33337b.jpg': array([0.47355717, 0.22187251, 0.38499987, ..., 0.2422892 , 0.10857618,
#        0.23511106], dtype=float32), '3659686168_49c3abcee1.jpg': array([0.5203805 , 0.36434317, 0.6464255 , ..., 0.88734174, 0.49748218,
#        0.68445444], dtype=float32), '3671262694_29fbeb9d95.jpg': array([0.08816864, 0.47747308, 0.25665188, ..., 0.9156089 , 0.0118552 ,
#        0.6699566 ], dtype=float32), '3672057606_cb6393dbd9.jpg': array([0.46254575, 0.5004787 , 0.10109368, ..., 0.11486643, 0.11936883,
#        0.24987154], dtype=float32), '3643074723_94d42b7a0c.jpg': array([0.54171735, 0.05314182, 0.3861701 , ..., 0.4010971 , 0.45910227,
#        0.0856234 ], dtype=float32), '36422830_55c844bc2d.jpg': array([0.3311989 , 0.12040898, 0.09729756, ..., 0.0353365 , 0.2509169 ,
#        0.11080086], dtype=float32), '3672106148_56cfb5fc8d.jpg': array([0.80276716, 0.1849179 , 0.2188422 , ..., 0.7008146 , 0.0706307 ,
#        0.11806497], dtype=float32), '3652859271_908ae0ae89.jpg': array([0.8487958 , 0.3482886 , 0.27280644, ..., 1.1140025 , 0.7505083 ,
#        0.5752053 ], dtype=float32), '3645080830_1d9ee2f50a.jpg': array([0.08273416, 0.67434645, 0.11541551, ..., 0.7697134 , 0.10704188,
#        0.42340326], dtype=float32), '3643684616_9d2be87a5a.jpg': array([0.47644174, 0.5057399 , 0.55858684, ..., 0.6469568 , 1.04529   ,
#        0.6527277 ], dtype=float32), '3643684044_a131168127.jpg': array([0.8084764 , 0.16702229, 0.5682966 , ..., 1.7538732 , 0.7982595 ,
#        1.2578117 ], dtype=float32), '3640661245_c8c419524d.jpg': array([0.75423837, 0.91520286, 0.35216677, ..., 0.32622406, 1.0235707 ,
#        0.7534283 ], dtype=float32), '3639845565_be547c38ba.jpg': array([0.6027771 , 0.03990912, 0.37753248, ..., 0.16655797, 0.27520853,
#        0.39180955], dtype=float32), '3665996775_6d7d9a46f1.jpg': array([1.3138149 , 0.1114984 , 0.7581523 , ..., 0.15636285, 1.2260022 ,
#        0.14424726], dtype=float32), '3640104986_5d8c9a9948.jpg': array([0.6754618 , 0.13731122, 1.9175935 , ..., 0.6240644 , 0.4838041 ,
#        0.13945717], dtype=float32), '3646453252_5ebbbaa6cc.jpg': array([0.04760691, 0.5525399 , 0.1434331 , ..., 0.8835509 , 0.2715652 ,
#        0.3366725 ], dtype=float32), '365274901_576b0f8241.jpg': array([0.26108968, 0.36157826, 0.13040641, ..., 0.73344195, 0.6124495 ,
#        0.19954738], dtype=float32), '3665987581_5e6b0a65f2.jpg': array([0.36101204, 0.31233802, 0.4389002 , ..., 0.22094035, 0.05724807,
#        0.7099198 ], dtype=float32), '364213568_7f83e7d144.jpg': array([0.128009  , 0.8348801 , 0.09654834, ..., 0.01429159, 0.2564165 ,
#        0.5933251 ], dtype=float32), '3667404919_b273df57e4.jpg': array([0.12954493, 0.31819776, 0.23724985, ..., 0.41897622, 0.7174771 ,
#        0.1622299 ], dtype=float32), '3640417354_b0b3e4aec9.jpg': array([0.44063008, 0.04064092, 0.37279233, ..., 0.04834878, 0.21389961,
#        0.37157553], dtype=float32), '3653462288_bfe2360a64.jpg': array([0.44474226, 0.35543907, 0.2662279 , ..., 0.23837031, 1.2039421 ,
#        0.06707653], dtype=float32), '3639684919_cb6fbf5638.jpg': array([0.8781501 , 0.6367302 , 1.7742822 , ..., 0.23591924, 0.67857623,
#        0.37089434], dtype=float32), '3665549027_d7fb05d157.jpg': array([0.3533327 , 0.4186902 , 0.45898604, ..., 0.18034065, 0.69148433,
#        0.349806  ], dtype=float32), '3653837067_94050699ec.jpg': array([0.0845464 , 0.6249856 , 0.36542955, ..., 0.09643256, 0.09039202,
#        0.9490166 ], dtype=float32), '3650986674_3e101c606b.jpg': array([0.22177263, 0.11992281, 0.16864426, ..., 0.12270258, 1.3604732 ,
#        0.40982574], dtype=float32), '3655773435_c234e94820.jpg': array([0.19639024, 0.00812091, 0.10048124, ..., 0.08975603, 0.77465546,
#        0.18728176], dtype=float32), '3672105509_53b13b2ed4.jpg': array([0.17724496, 0.2827422 , 0.22766215, ..., 0.156746  , 0.06246076,
#        0.18542352], dtype=float32), '3657503733_9888ccf05e.jpg': array([0.2740949 , 0.14085928, 0.13298862, ..., 0.04507785, 0.34636226,
#        0.13982534], dtype=float32), '3649224118_abe73c672c.jpg': array([0.2731255 , 0.13801324, 0.5535823 , ..., 0.7365422 , 0.69642437,
#        0.48726726], dtype=float32), '366713533_bd6d48cf02.jpg': array([0.56303126, 0.434531  , 0.6886715 , ..., 0.56906474, 0.40803778,
#        0.20242211], dtype=float32), '3673032164_6c6843de87.jpg': array([0.6397556 , 0.22783324, 0.37168062, ..., 0.2830336 , 0.14704561,
#        0.5530788 ], dtype=float32), '3640407952_bb38fb9d55.jpg': array([0.27410197, 0.18707508, 0.30903602, ..., 0.01560941, 0.51340985,
#        0.18151268], dtype=float32), '3666056567_661e25f54c.jpg': array([1.0416983 , 0.15534076, 0.6690351 , ..., 0.04371903, 0.31469926,
#        0.57162905], dtype=float32), '3653764864_225958c9c1.jpg': array([0.1320864 , 0.6703311 , 0.00314957, ..., 0.24182607, 0.21689266,
#        0.19594872], dtype=float32), '3650188378_cc8aea89f0.jpg': array([0.23118487, 0.33022416, 0.6562127 , ..., 0.27572614, 0.03068597,
#        0.13467243], dtype=float32), '3660361818_e05367693f.jpg': array([0.3054913 , 0.6450315 , 0.05753867, ..., 0.6129639 , 1.3183962 ,
#        0.11290678], dtype=float32), '3666324102_18ecdf8253.jpg': array([0.01643478, 0.15558575, 0.6644695 , ..., 0.23519568, 0.01453229,
#        0.08416095], dtype=float32), '3676561090_9828a9f6d0.jpg': array([0.73265505, 0.25011152, 0.04151443, ..., 0.16020772, 0.47519845,
#        1.0615677 ], dtype=float32), '3668900592_a84b0c07db.jpg': array([0.32329842, 0.06071901, 0.13984618, ..., 0.46258634, 1.2065703 ,
#        0.5149349 ], dtype=float32), '366548880_3d3e914746.jpg': array([0.08161555, 0.46322843, 0.25722578, ..., 0.46332797, 1.4956434 ,
#        0.46112758], dtype=float32), '3674565156_14d3b41450.jpg': array([1.1091115 , 0.3045063 , 0.6251133 , ..., 0.9069228 , 1.002333  ,
#        0.42386347], dtype=float32), '3659769138_d907fd9647.jpg': array([0.11474732, 0.16642727, 0.3925657 , ..., 0.49839813, 0.31440768,
#        0.31159738], dtype=float32), '3662909101_21b9e59a3e.jpg': array([0.4330877 , 0.27831563, 0.05981419, ..., 0.15256682, 0.48756242,
#        0.15087174], dtype=float32), '3661072592_2e693cd5a0.jpg': array([0.20945117, 0.66741765, 1.2353843 , ..., 0.25469843, 1.2136717 ,
#        0.52713054], dtype=float32), '3675825945_96b2916959.jpg': array([0.28485882, 0.04955671, 0.07200052, ..., 0.34747756, 0.20137604,
#        0.8703188 ], dtype=float32), '3639704469_fe83e1c9b7.jpg': array([0.55370307, 0.19744548, 1.0656178 , ..., 0.5577004 , 0.3868073 ,
#        0.03974315], dtype=float32), '3649384501_f1e06c58c0.jpg': array([0.18892248, 0.6373034 , 1.0553875 , ..., 0.2786302 , 0.55018306,
#        0.1002175 ], dtype=float32), '3639428663_dae5e8146e.jpg': array([0.6539911 , 0.77721864, 0.4770685 , ..., 1.3760769 , 0.19848225,
#        0.06931904], dtype=float32), '3661239105_973f8216c4.jpg': array([0.4222796 , 0.8210596 , 0.01804312, ..., 0.10041147, 0.7526947 ,
#        0.3675497 ], dtype=float32), '3652572138_34d6b72999.jpg': array([0.22568537, 0.18144926, 0.29935563, ..., 0.        , 0.26133746,
#        0.27891946], dtype=float32), '3656030945_fa003bd696.jpg': array([0.45651528, 0.43687987, 0.6723529 , ..., 0.7800646 , 0.38496858,
#        0.29913265], dtype=float32), '3651107058_d84d4c3c25.jpg': array([0.26158732, 0.05729001, 0.27236348, ..., 0.40159225, 0.        ,
#        0.05887686], dtype=float32), '365584746_681f33fa46.jpg': array([0.14626488, 0.81752354, 0.30503032, ..., 0.16582137, 0.6774993 ,
#        0.27527347], dtype=float32), '3675685612_3987d91d92.jpg': array([0.23850776, 0.5808511 , 0.10550576, ..., 0.96967345, 0.34420326,
#        0.20845303], dtype=float32), '365759754_6cf7068c9a.jpg': array([0.33285183, 0.32627285, 0.10813664, ..., 0.29293174, 0.86775804,
#        0.18803102], dtype=float32), '3669069522_555c97fbfb.jpg': array([0.29998878, 0.154212  , 0.23167698, ..., 0.02972873, 0.01887849,
#        0.07918809], dtype=float32), '3662871327_b128d25f04.jpg': array([0.32144657, 0.3838905 , 0.6288309 , ..., 0.5050669 , 0.19351204,
#        0.70238334], dtype=float32), '3667492609_97f88b373f.jpg': array([0.16627946, 0.05854325, 0.410522  , ..., 0.5631771 , 0.675429  ,
#        0.24539486], dtype=float32), '3647446816_bd4383c828.jpg': array([0.10281248, 0.14169033, 0.16095641, ..., 0.09273104, 0.48564744,
#        0.47048858], dtype=float32), '3649802021_8a689bc153.jpg': array([0.17744598, 0.39540583, 0.20912218, ..., 0.496686  , 0.12542203,
#        0.6611749 ], dtype=float32), '3667318593_fa1816b346.jpg': array([0.29253724, 0.29823613, 0.330124  , ..., 0.4386052 , 0.23270778,
#        0.56931144], dtype=float32), '3675742996_02ccef16a3.jpg': array([0.6415986 , 0.2827136 , 0.6434852 , ..., 1.1935095 , 1.0337279 ,
#        0.37334228], dtype=float32), '3638783842_af08dbb518.jpg': array([0.84096587, 0.8580693 , 1.7200255 , ..., 0.11593117, 1.5177072 ,
#        0.13690878], dtype=float32), '3667908724_65c7d112f2.jpg': array([1.3117691 , 0.5959054 , 0.46132487, ..., 2.5838437 , 0.6407329 ,
#        0.6864087 ], dtype=float32), '3672940355_47f30e2b28.jpg': array([0.35107976, 0.15631561, 0.29394746, ..., 0.39109412, 0.38942152,
#        0.08216882], dtype=float32), '3648988742_888a16f600.jpg': array([0.5480341 , 0.3713618 , 0.23120008, ..., 0.87097216, 0.05812144,
#        0.15464634], dtype=float32), '3670075789_92ea9a183a.jpg': array([0.33345354, 0.14687996, 0.5023457 , ..., 0.16296537, 0.45778534,
#        0.1737323 ], dtype=float32), '3656906086_7034f69ab6.jpg': array([0.386571  , 0.21186306, 0.295739  , ..., 0.16283852, 0.1041017 ,
#        0.7316277 ], dtype=float32), '3666537170_c4ecda4be8.jpg': array([0.1379813 , 0.02515719, 0.49748066, ..., 0.09622915, 0.9735921 ,
#        0.20352899], dtype=float32), '3640241166_b1ab7a8e7a.jpg': array([0.4042471 , 0.35085723, 0.20372191, ..., 0.5976918 , 0.0539168 ,
#        0.03858707], dtype=float32), '3666574371_317b008d2a.jpg': array([0.07533626, 0.24003714, 0.2632293 , ..., 0.04801911, 0.11092851,
#        0.04713026], dtype=float32), '3649307685_60c1294d2a.jpg': array([0.26296484, 0.5481808 , 0.05487686, ..., 0.1967862 , 0.31090203,
#        0.27202612], dtype=float32), '3649916507_b88a3d2082.jpg': array([0.12608272, 0.65663016, 0.15636417, ..., 0.47381115, 0.235982  ,
#        0.30273023], dtype=float32), '3654338683_13b2f95a9a.jpg': array([0.1882108 , 0.33262646, 0.07113813, ..., 0.09279419, 0.91266894,
#        0.00251122], dtype=float32), '3671933270_d124e9a1a4.jpg': array([0.244875  , 0.38061184, 0.05367613, ..., 0.36837208, 0.6495439 ,
#        0.21444649], dtype=float32), '3643087589_627a0a9e01.jpg': array([0.15209773, 0.3612613 , 0.08877886, ..., 0.02769269, 0.5052002 ,
#        1.1682152 ], dtype=float32), '3655326478_4472c5c630.jpg': array([0.3096129 , 0.69141185, 0.6190787 , ..., 0.00250776, 0.33759078,
#        0.16693977], dtype=float32), '3667157255_4e66d11dc2.jpg': array([0.52705145, 0.59574324, 1.4176934 , ..., 1.3282206 , 0.90041053,
#        0.2027775 ], dtype=float32), '3640870001_acbd1d5ceb.jpg': array([0.08884145, 0.26909852, 0.6181973 , ..., 0.58883977, 0.6400062 ,
#        0.26991093], dtype=float32), '365128300_6966058139.jpg': array([0.49506378, 0.08819178, 0.18556578, ..., 0.32783213, 1.2005597 ,
#        0.17677388], dtype=float32), '3671935691_57bdd0e778.jpg': array([0.8245758 , 0.9262482 , 1.2890499 , ..., 0.14093083, 1.1407536 ,
#        0.46057558], dtype=float32), '3676432043_0ca418b861.jpg': array([0.42725313, 0.1360332 , 0.385526  , ..., 0.5189107 , 0.20341133,
#        0.16075489], dtype=float32), '3647826834_dc63e21bd0.jpg': array([0.6346431 , 0.24320279, 0.458867  , ..., 0.04635411, 0.2328914 ,
#        0.00708731], dtype=float32), '3661659196_6ed90f96c0.jpg': array([0.34362566, 0.15044896, 0.9349952 , ..., 0.19596528, 1.1820743 ,
#        0.40174085], dtype=float32), '3673970325_4e025069e9.jpg': array([0.05253066, 1.0980554 , 0.17867012, ..., 0.29909477, 1.0100029 ,
#        0.01584813], dtype=float32), '3666169738_a8c74cf745.jpg': array([0.30935153, 0.2210204 , 0.17452687, ..., 0.8739681 , 1.1435878 ,
#        1.1777617 ], dtype=float32), '3647693147_0d0434351b.jpg': array([0.24464136, 0.29399902, 0.33450663, ..., 0.7497164 , 1.2778909 ,
#        0.18202774], dtype=float32), '3669564923_8fcb1a6eff.jpg': array([1.8150431 , 0.42093825, 1.021587  , ..., 0.3983249 , 0.59066546,
#        0.45345634], dtype=float32), '3646970605_d25c25340b.jpg': array([0.4855739 , 0.6398989 , 1.1766524 , ..., 0.03287717, 0.35071233,
#        0.7749512 ], dtype=float32), '3667822570_d39850e217.jpg': array([0.05967779, 0.26862937, 0.0769698 , ..., 0.26342452, 0.60098743,
#        0.55069906], dtype=float32), '3666188047_e81e1d97a7.jpg': array([0.67876846, 0.09916566, 0.43724307, ..., 0.35771918, 0.630133  ,
#        0.21446088], dtype=float32), '3639105305_bd9cb2d1db.jpg': array([0.15347011, 0.17076145, 0.7980497 , ..., 0.31264114, 0.17457595,
#        0.55515015], dtype=float32), '3640020134_367941f5ec.jpg': array([0.14391923, 0.15571119, 0.6329573 , ..., 0.15986833, 1.8557436 ,
#        0.09188304], dtype=float32), '3648081498_76ec091495.jpg': array([0.2608788 , 0.27790627, 0.16698273, ..., 0.639903  , 0.10078554,
#        0.7072534 ], dtype=float32), '3648160673_0c783236a6.jpg': array([0.05179279, 0.43584538, 0.32055086, ..., 0.7117183 , 0.96720564,
#        0.46338555], dtype=float32), '3671950830_b570bac1b9.jpg': array([0.03031103, 0.18261749, 0.15926012, ..., 0.38513768, 0.08617385,
#        0.39182177], dtype=float32), '3674168459_6245f4f658.jpg': array([0.13760173, 0.1627669 , 0.15176183, ..., 0.24154693, 0.61715406,
#        0.32385832], dtype=float32), '3668984985_b60ceb2ae9.jpg': array([0.6489464 , 0.17753467, 0.5844706 , ..., 0.03635007, 0.17936191,
#        0.33535162], dtype=float32), '3659090958_a56913ca68.jpg': array([0.44724214, 0.39101663, 0.12908718, ..., 0.09835665, 0.13218123,
#        0.149375  ], dtype=float32), '3638783120_f600ceb19d.jpg': array([0.29549384, 0.31251395, 0.34538776, ..., 0.2528914 , 0.22490036,
#        0.30327848], dtype=float32), '3639547922_0b00fed5cd.jpg': array([0.19701542, 0.04186992, 0.4741683 , ..., 0.62098515, 0.8540307 ,
#        0.0139172 ], dtype=float32), '3656104088_a0d1642fa9.jpg': array([0.3492689 , 0.3214576 , 0.23595089, ..., 0.09167999, 0.06414117,
#        0.5992286 ], dtype=float32), '3658016590_f761e72dc3.jpg': array([0.26809427, 0.13232021, 0.33906868, ..., 0.3127723 , 0.08497691,
#        0.27526337], dtype=float32), '3638908276_b1751d30ff.jpg': array([0.49279135, 0.8255131 , 0.30619478, ..., 0.5955768 , 0.75592947,
#        0.66312116], dtype=float32), '3699522388_2333f01f40.jpg': array([0.36032736, 0.15157193, 0.3987471 , ..., 0.53606886, 0.09405133,
#        0.        ], dtype=float32), '3707990914_843e8f15f1.jpg': array([0.6913762 , 0.04775267, 0.24610226, ..., 0.05970129, 0.52947366,
#        1.1852537 ], dtype=float32), '3691592651_6e4e7f1da9.jpg': array([1.1619775 , 0.14184746, 0.11900595, ..., 0.2592899 , 0.08977236,
#        0.65315235], dtype=float32), '3694071771_ce760db4c7.jpg': array([0.10948631, 0.52937853, 0.04804516, ..., 0.4826976 , 1.317498  ,
#        1.152023  ], dtype=float32), '3691622437_f13644273c.jpg': array([1.0825591 , 0.44519436, 1.0362785 , ..., 0.8705335 , 0.9817348 ,
#        0.        ], dtype=float32), '3695517194_2a6b604cb2.jpg': array([0.08745715, 0.25942388, 0.21894036, ..., 0.29241422, 0.4696314 ,
#        0.22502321], dtype=float32), '3682038869_585075b5ff.jpg': array([0.16368723, 0.19266109, 0.32454598, ..., 0.19169766, 0.30023575,
#        0.12557687], dtype=float32), '3692836015_d11180727b.jpg': array([0.24374819, 0.16656855, 0.07060905, ..., 0.01498262, 0.17084187,
#        0.14023003], dtype=float32), '3701509233_a2275a4e57.jpg': array([0.16851735, 0.09192358, 0.10907443, ..., 0.11374538, 0.55551684,
#        0.04527181], dtype=float32), '3701249979_8bc757e171.jpg': array([0.28348905, 0.7862023 , 0.9641038 , ..., 0.11039733, 0.7218933 ,
#        0.18727069], dtype=float32), '3703960010_1e4c922a25.jpg': array([0.6049698 , 0.47328812, 1.8091594 , ..., 0.6190816 , 0.06392525,
#        0.178958  ], dtype=float32), '3705688385_47651205d3.jpg': array([0.18422231, 0.20154382, 0.40089607, ..., 0.18389937, 0.95607924,
#        0.8502822 ], dtype=float32), '3681651647_08eba60f89.jpg': array([0.9607445 , 0.7134458 , 1.862963  , ..., 0.07274269, 1.4892716 ,
#        0.57113385], dtype=float32), '3678100844_e3a9802471.jpg': array([0.42379668, 0.6767821 , 0.5435991 , ..., 0.6885214 , 0.62558806,
#        0.35513604], dtype=float32), '3687222696_85bf6f78f7.jpg': array([0.283634  , 0.17332879, 0.26085615, ..., 0.34310198, 0.46178472,
#        0.28228486], dtype=float32), '3693297007_94512e861e.jpg': array([0.37693685, 0.6707821 , 0.3371541 , ..., 0.19959696, 0.7876898 ,
#        0.1720261 ], dtype=float32), '3679341667_936769fd0c.jpg': array([0.28194672, 0.2507052 , 0.13489011, ..., 0.48382676, 0.2354797 ,
#        0.25984383], dtype=float32), '3676788491_01e9bc5f15.jpg': array([0.40921652, 0.60792184, 0.49417034, ..., 0.14989361, 0.23334216,
#        1.1853331 ], dtype=float32), '3684680947_f1c460242f.jpg': array([0.21357292, 0.19611289, 0.20570247, ..., 0.4636259 , 0.22171704,
#        0.21342248], dtype=float32), '3677329561_fa3e1fdcf9.jpg': array([0.51332486, 0.37541825, 0.5071204 , ..., 0.6847523 , 0.21675226,
#        0.35761032], dtype=float32), '3683592946_262e9bfbfd.jpg': array([0.09133634, 0.09664889, 0.08649551, ..., 0.12129319, 0.01991242,
#        0.04119322], dtype=float32), '367964525_b1528ac6e4.jpg': array([0.46207112, 0.3069194 , 0.38121074, ..., 0.8130632 , 0.64869   ,
#        0.05247306], dtype=float32), '3677927146_1696f0b075.jpg': array([0.30339366, 0.9483343 , 0.02663505, ..., 0.47672534, 0.23748556,
#        0.4561505 ], dtype=float32), '3703035378_c6034cac51.jpg': array([0.5805182 , 1.0543172 , 0.66010046, ..., 0.00780573, 1.5318606 ,
#        0.22840822], dtype=float32), '3688839836_ba5e4c24fc.jpg': array([0.3746534 , 0.7617825 , 0.8392035 , ..., 0.4242699 , 0.9545927 ,
#        0.18771099], dtype=float32), '3677239603_95865a9073.jpg': array([0.80139256, 0.30238098, 0.5423803 , ..., 0.2661324 , 0.52631974,
#        0.06973398], dtype=float32), '3681575323_433d007650.jpg': array([0.43192476, 0.15053806, 0.9739406 , ..., 0.16312113, 1.1254897 ,
#        0.39799914], dtype=float32), '3677860841_3aa9d8036c.jpg': array([0.596812  , 0.21587718, 0.533428  , ..., 0.42637858, 1.0743039 ,
#        0.14156124], dtype=float32), '3704995657_e2e114083d.jpg': array([0.30600467, 0.30186296, 0.05619229, ..., 0.05465018, 0.80753475,
#        0.34002393], dtype=float32), '3708244207_0d3a2b2f92.jpg': array([0.5216577 , 0.16836467, 0.11899905, ..., 0.3329636 , 0.6703632 ,
#        0.15967566], dtype=float32), '3710674892_857b8056f7.jpg': array([7.5086963e-01, 3.7400541e-01, 1.0120301e-01, ..., 1.2545775e+00,
#        3.6343161e-04, 8.9257099e-02], dtype=float32), '3702607829_2b8b3e65ab.jpg': array([0.31369132, 0.19662315, 0.3760878 , ..., 0.57053494, 0.28544787,
#        0.2756889 ], dtype=float32), '369244499_752f0c1018.jpg': array([0.09643475, 0.30034167, 0.42667428, ..., 0.43858725, 0.77466166,
#        1.2527171 ], dtype=float32), '3679707139_1cc1e71237.jpg': array([0.36536762, 0.07094719, 0.4223323 , ..., 0.12240615, 0.5248016 ,
#        0.05964957], dtype=float32), '3710073758_ac2b217f29.jpg': array([0.46618778, 0.30398995, 0.49337265, ..., 1.9669392 , 0.62553036,
#        0.01804556], dtype=float32), '3683185795_704f445bf4.jpg': array([0.6757656 , 0.19424084, 0.95154506, ..., 0.59502554, 0.8745864 ,
#        0.03374166], dtype=float32), '3687996279_05b5a2a706.jpg': array([0.40374452, 1.1025233 , 0.838624  , ..., 0.25006288, 0.06450401,
#        0.27150887], dtype=float32), '3706356018_28f62290e8.jpg': array([0.58650047, 0.47384113, 1.1047494 , ..., 0.6756499 , 0.09642113,
#        0.49173862], dtype=float32), '3677613006_4689cb8e4e.jpg': array([0.8548497 , 0.767443  , 0.5524807 , ..., 0.3426088 , 1.0140679 ,
#        0.36763304], dtype=float32), '3701878677_8f2c26227b.jpg': array([0.29158106, 0.14126521, 0.38261616, ..., 0.557158  , 0.84974176,
#        0.08174627], dtype=float32), '3709030554_02301229ea.jpg': array([0.18121834, 0.25761697, 0.15831357, ..., 0.38534695, 0.2652324 ,
#        0.04957158], dtype=float32), '3681172959_6674c118d2.jpg': array([1.2200246 , 0.6539606 , 0.20500225, ..., 0.43340316, 0.17964858,
# ...
#        0.39947045], dtype=float32), '2068465241_3bcabacfd7.jpg': array([0.26619995, 0.16270903, 0.31432644, ..., 0.5007946 , 0.17548573,
#        0.6532455 ], dtype=float32), '2110898123_07729c1461.jpg': array([0.19785175, 0.32282364, 0.11960801, ..., 0.39431682, 0.00212161,
#        0.00800029], dtype=float32), '2081141788_38fa84ce3c.jpg': array([1.0769227 , 0.14866163, 1.0860361 , ..., 0.77846396, 0.9026332 ,
#        0.17400289], dtype=float32), '2098418613_85a0c9afea.jpg': array([0.0483396 , 0.08761643, 0.28205365, ..., 0.10449286, 1.0099187 ,
#        0.75025433], dtype=float32), '2075041394_0b3ea1822d.jpg': array([0.08377087, 0.23903066, 0.05670277, ..., 0.87558436, 0.04179729,
#        0.15574524], dtype=float32), '2055646179_169807fed4.jpg': array([0.18173216, 0.33333623, 0.5599726 , ..., 0.0260375 , 0.04648752,
#        0.57523555], dtype=float32), '2056041678_d6b5b39b26.jpg': array([0.19638076, 0.18030292, 0.22685486, ..., 0.7821666 , 0.78795236,
#        0.9666881 ], dtype=float32), '2095007523_591f255708.jpg': array([0.20181933, 0.4982667 , 0.1010461 , ..., 0.25043696, 0.1791736 ,
#        0.15501517], dtype=float32), '2107837987_ffecfc367a.jpg': array([0.99102855, 0.2569309 , 0.5281422 , ..., 1.1387216 , 0.5909221 ,
#        0.04344934], dtype=float32), '2092870249_90e3f1855b.jpg': array([0.24410424, 0.00526498, 0.5570999 , ..., 0.33043638, 0.10704632,
#        0.4684631 ], dtype=float32), '2054308369_f9c6ec7815.jpg': array([0.08090787, 0.13260093, 0.23313734, ..., 0.60591626, 0.12692052,
#        0.00485417], dtype=float32), '2196284168_76417efbec.jpg': array([0.39198753, 0.20171839, 0.07394948, ..., 0.54783255, 0.02543476,
#        0.05975914], dtype=float32), '2140747429_62cfd89ae9.jpg': array([0.5334282 , 0.13569501, 0.58961916, ..., 0.68151695, 0.685678  ,
#        1.098428  ], dtype=float32), '2192475933_d779bf42eb.jpg': array([0.41617256, 0.14449415, 0.31068522, ..., 0.7562685 , 0.21933614,
#        0.46882203], dtype=float32), '2149968397_a7411729d1.jpg': array([0.6246259 , 0.11747964, 0.59478694, ..., 0.09623092, 0.66806984,
#        0.1577406 ], dtype=float32), '2150564996_d173a506d7.jpg': array([0.18974394, 0.2606612 , 0.26660004, ..., 0.15139328, 0.10108383,
#        0.34493932], dtype=float32), '2138487671_5b89104043.jpg': array([0.1286202 , 0.09302893, 0.34422392, ..., 0.400437  , 0.876469  ,
#        0.3589819 ], dtype=float32), '219730733_6a55382dd2.jpg': array([0.31461036, 0.44567847, 0.4357131 , ..., 0.41537455, 0.90643007,
#        0.19856785], dtype=float32), '2131762850_5293a288d9.jpg': array([0.10661907, 0.4025329 , 0.5569762 , ..., 1.1498785 , 0.7590965 ,
#        0.97533596], dtype=float32), '2173312932_269f9786fc.jpg': array([0.21299435, 0.2559063 , 0.08469848, ..., 0.07040904, 0.5175729 ,
#        0.11088913], dtype=float32), '2195620255_6693479734.jpg': array([0.08445565, 0.25642067, 0.20918117, ..., 0.21322326, 0.9594579 ,
#        0.34212768], dtype=float32), '2191453879_11dfe2ba3a.jpg': array([0.13129756, 0.31269854, 0.11653768, ..., 0.31350422, 0.0860633 ,
#        0.1636942 ], dtype=float32), '2181846120_3744ca3942.jpg': array([0.09380107, 0.40772682, 0.2367935 , ..., 0.59196126, 0.12397292,
#        0.08415559], dtype=float32), '2144049642_070cf541b4.jpg': array([0.04492839, 0.5774648 , 0.51614493, ..., 1.1919479 , 0.4273187 ,
#        1.101901  ], dtype=float32), '2135360514_7dcb9ed796.jpg': array([0.05752767, 0.38518196, 0.46663254, ..., 0.5998794 , 0.19747692,
#        0.44854945], dtype=float32), '2195887578_3ba2f29b48.jpg': array([0.27831087, 0.16362695, 1.2598343 , ..., 0.02585742, 0.08841397,
#        0.17263052], dtype=float32), '2139519215_8ca16dd192.jpg': array([0.940352  , 0.5391722 , 0.45988122, ..., 0.8774754 , 0.9409332 ,
#        0.6276065 ], dtype=float32), '2116444946_1f5d1fe5d1.jpg': array([0.13904189, 0.31785232, 0.24077542, ..., 1.2823887 , 0.9587263 ,
#        0.5995005 ], dtype=float32), '2125216241_5b265a2fbc.jpg': array([0.02966044, 0.08421694, 0.06330898, ..., 0.10203338, 0.19587272,
#        0.11417732], dtype=float32), '2178306830_6af49375b4.jpg': array([0.03534855, 0.01414654, 0.01468411, ..., 0.08159915, 0.14041442,
#        0.33098325], dtype=float32), '2186139563_e60c1d4b8b.jpg': array([0.6541989 , 0.32824016, 0.19787866, ..., 0.41452116, 0.668486  ,
#        0.60523117], dtype=float32), '2151300603_248a9fe715.jpg': array([0.23867902, 0.24779728, 0.36540636, ..., 0.3983128 , 1.2274994 ,
#        1.1234705 ], dtype=float32), '2178064851_bb39652d28.jpg': array([0.525914  , 0.06035457, 0.7754101 , ..., 0.10006222, 0.4329437 ,
#        0.10893967], dtype=float32), '2129430111_338a94f8fb.jpg': array([0.09585042, 0.05142285, 0.1222675 , ..., 0.29578495, 1.683218  ,
#        0.30402577], dtype=float32), '2188192752_09d9fc5431.jpg': array([0.33224297, 0.14915891, 0.50805277, ..., 0.03232408, 0.21857946,
#        0.06073115], dtype=float32), '2162469360_ff777edc95.jpg': array([0.04971342, 0.37637964, 0.06436062, ..., 0.28447914, 0.11156882,
#        0.33438367], dtype=float32), '2201222219_8d656b0633.jpg': array([0.46572566, 0.95974374, 0.45489237, ..., 0.41209954, 0.26461077,
#        0.07904643], dtype=float32), '2205088706_d7e633e00d.jpg': array([0.6061567 , 0.07652572, 0.34227258, ..., 0.20525272, 0.33140796,
#        0.62697697], dtype=float32), '2204777844_1bcf26bf84.jpg': array([0.0641503 , 0.28400573, 0.24974672, ..., 0.3399201 , 0.30674788,
#        0.30418196], dtype=float32), '2194806429_ca4c3770c1.jpg': array([0.4690005 , 0.12153915, 0.64479107, ..., 0.04865396, 0.9868638 ,
#        0.04615049], dtype=float32), '2159447283_fab8c272b0.jpg': array([0.617476  , 0.57134473, 0.2932476 , ..., 0.01033604, 0.3303699 ,
#        0.41718897], dtype=float32), '2127209046_94711c747b.jpg': array([0.10949001, 0.01659358, 0.29184586, ..., 0.        , 0.19105414,
#        0.05293192], dtype=float32), '2198964806_c57b0534d3.jpg': array([0.08952655, 0.30057326, 0.0659797 , ..., 0.20788199, 0.38731804,
#        0.6329566 ], dtype=float32), '102455176_5f8ead62d5.jpg': array([0.1828115 , 0.15919721, 0.1742554 , ..., 0.69254124, 0.23620935,
#        0.05880404], dtype=float32), '1015584366_dfcec3c85a.jpg': array([0.453228  , 0.42908317, 0.20216328, ..., 0.35689455, 0.38221973,
#        0.1598439 ], dtype=float32), '1028205764_7e8df9a2ea.jpg': array([0.15151456, 0.20331211, 0.36801288, ..., 0.11727437, 0.29092348,
#        0.39519247], dtype=float32), '1022975728_75515238d8.jpg': array([4.1625410e-01, 1.8792866e-02, 2.0406577e-01, ..., 1.0387027e-03,
#        1.2464397e+00, 3.7836432e-02], dtype=float32), '1030985833_b0902ea560.jpg': array([0.27375457, 0.259237  , 0.11926934, ..., 0.19077478, 0.3737925 ,
#        0.41446823], dtype=float32), '1019077836_6fc9b15408.jpg': array([0.34666276, 0.43229014, 0.25743935, ..., 0.32528073, 0.42775822,
#        0.4459875 ], dtype=float32), '101654506_8eb26cfb60.jpg': array([0.15644166, 0.61721206, 0.03327081, ..., 0.2245073 , 1.5899545 ,
#        0.6303818 ], dtype=float32), '1009434119_febe49276a.jpg': array([0.53460914, 1.3676211 , 0.7804355 , ..., 0.39463884, 0.88772273,
#        1.0728819 ], dtype=float32), '1022454428_b6b660a67b.jpg': array([0.4963347 , 0.19245845, 0.40163767, ..., 0.934418  , 0.7397382 ,
#        0.06167337], dtype=float32), '1020651753_06077ec457.jpg': array([0.4751468 , 0.35221812, 0.01383337, ..., 0.20678748, 0.06418341,
#        0.3813911 ], dtype=float32), '101669240_b2d3e7f17b.jpg': array([0.10859612, 1.2652323 , 0.09501712, ..., 0.45106274, 0.9349952 ,
#        0.2054165 ], dtype=float32), '1016887272_03199f49c4.jpg': array([0.13507546, 0.15651292, 0.6852761 , ..., 0.6462797 , 0.21949852,
#        0.3609019 ], dtype=float32), '1032460886_4a598ed535.jpg': array([0.59063655, 0.08231174, 0.59571767, ..., 0.278556  , 0.40730202,
#        0.17353703], dtype=float32), '103205630_682ca7285b.jpg': array([0.27082816, 0.15861729, 0.09538765, ..., 0.08660232, 0.16321447,
#        0.44893557], dtype=float32), '1026685415_0431cbf574.jpg': array([0.39191973, 0.37633237, 0.1939192 , ..., 0.5305965 , 0.28704038,
#        0.38361484], dtype=float32), '1002674143_1b742ab4b8.jpg': array([0.3735192 , 0.24596635, 0.96352893, ..., 1.1459348 , 0.2654001 ,
#        0.0198314 ], dtype=float32), '1000268201_693b08cb0e.jpg': array([0.12277575, 0.33294916, 0.75271565, ..., 0.21939662, 0.3021646 ,
#        0.40283215], dtype=float32), '1007320043_627395c3d8.jpg': array([0.17231002, 0.49808306, 0.21576932, ..., 0.09676188, 1.229847  ,
#        0.5421413 ], dtype=float32), '1024138940_f1fefbdce1.jpg': array([0.32591918, 0.98454225, 0.4927305 , ..., 0.3638925 , 0.99272096,
#        0.9708174 ], dtype=float32), '1015118661_980735411b.jpg': array([0.23118493, 0.12729673, 0.3962006 , ..., 0.05209988, 0.59356093,
#        0.8125439 ], dtype=float32), '1012212859_01547e3f17.jpg': array([0.2402941 , 1.086235  , 0.04511423, ..., 0.00142682, 0.09226677,
#        0.79246503], dtype=float32), '1007129816_e794419615.jpg': array([0.21595308, 0.15582064, 0.29477093, ..., 0.40564913, 0.16532087,
#        0.3741695 ], dtype=float32), '1001773457_577c3a7d70.jpg': array([0.7366836 , 0.591133  , 0.181942  , ..., 0.16030231, 0.34144694,
#        0.9083165 ], dtype=float32), '1019604187_d087bf9a5f.jpg': array([0.38632035, 1.2523953 , 0.28417975, ..., 0.05141539, 0.965613  ,
#        0.28555664], dtype=float32), '103195344_5d2dc613a3.jpg': array([0.10363413, 0.65924054, 0.04707839, ..., 0.51623553, 0.5699529 ,
#        0.12665519], dtype=float32), '1003163366_44323f5815.jpg': array([0.48603076, 0.29218352, 0.31436825, ..., 0.9825511 , 0.28108013,
#        0.22330126], dtype=float32), '102351840_323e3de834.jpg': array([0.10465103, 0.20573787, 0.19238386, ..., 0.15708329, 0.43167943,
#        0.26807785], dtype=float32), '1096097967_ac305887b4.jpg': array([1.0365374 , 0.37706637, 0.27563065, ..., 1.3829296 , 0.4180557 ,
#        0.70282495], dtype=float32), '10815824_2997e03d76.jpg': array([0.34266388, 0.16739699, 0.09924407, ..., 0.21216713, 0.46709567,
#        0.25276437], dtype=float32), '109823397_e35154645f.jpg': array([0.20863657, 0.22773126, 0.15206139, ..., 0.4824591 , 0.10753526,
#        0.17774458], dtype=float32), '118309463_a532b75be9.jpg': array([0.09294854, 0.26968217, 0.6476371 , ..., 1.07513   , 0.00945387,
#        0.36787122], dtype=float32), '1191338263_a4fa073154.jpg': array([0.86051786, 0.66821563, 0.18008998, ..., 0.51470876, 1.4117184 ,
#        0.03145076], dtype=float32), '1118557877_736f339752.jpg': array([0.583392  , 0.53759885, 0.53417593, ..., 0.4580745 , 2.2388353 ,
#        0.22642545], dtype=float32), '1096165011_cc5eb16aa6.jpg': array([0.74661994, 0.15928605, 0.04334403, ..., 0.03396571, 0.89170396,
#        0.88603437], dtype=float32), '1056873310_49c665eb22.jpg': array([0.04073849, 0.0480077 , 0.7578236 , ..., 0.50066054, 1.2806255 ,
#        0.32564402], dtype=float32), '1121416483_c7902d0d49.jpg': array([0.39051542, 0.37338346, 0.25316364, ..., 0.33554244, 0.28968722,
#        0.00174673], dtype=float32), '109738916_236dc456ac.jpg': array([0.20451722, 0.09654921, 0.15033558, ..., 0.2532186 , 0.19424361,
#        0.8111638 ], dtype=float32), '1225443522_1633e7121f.jpg': array([0.86093044, 0.34319556, 0.16961247, ..., 0.2868638 , 0.27512777,
#        0.44977182], dtype=float32), '1052358063_eae6744153.jpg': array([0.30546322, 0.81699145, 0.45037973, ..., 0.05353823, 0.08843493,
#        0.07870084], dtype=float32), '1231229740_8dcbf80bfb.jpg': array([0.12246083, 0.3411048 , 0.15927918, ..., 0.4865304 , 0.01567064,
#        0.01904639], dtype=float32), '1163282319_b729b24c46.jpg': array([0.13218962, 0.15944809, 0.5446728 , ..., 0.62923545, 1.1282554 ,
#        0.35822535], dtype=float32), '1089181217_ee1167f7af.jpg': array([0.16025868, 0.36980432, 0.01681321, ..., 0.03328471, 0.01581269,
#        0.2055169 ], dtype=float32), '1167662968_e466f1e80a.jpg': array([0.0515324 , 0.28052595, 0.06461851, ..., 0.12887454, 0.16837993,
#        0.63880765], dtype=float32), '1236951314_0308dc4138.jpg': array([0.5948756 , 0.37337536, 0.06626055, ..., 0.20819394, 0.22866938,
#        0.25911465], dtype=float32), '109260216_85b0be5378.jpg': array([0.05363015, 1.3092134 , 0.1129424 , ..., 0.34922636, 0.64764386,
#        0.5314592 ], dtype=float32), '1193116658_c0161c35b5.jpg': array([0.17282169, 0.64822674, 0.4993054 , ..., 0.28620446, 0.18933238,
#        0.27283016], dtype=float32), '1095476286_87d4f8664e.jpg': array([0.05909821, 0.55430025, 0.47325134, ..., 0.3357964 , 0.1360513 ,
#        0.01928167], dtype=float32), '1235685934_be89b231fb.jpg': array([0.24498366, 0.46796456, 0.48111904, ..., 0.7354928 , 0.8058951 ,
#        0.20847112], dtype=float32), '1143882946_1898d2eeb9.jpg': array([0.2967457 , 0.2170845 , 0.24164477, ..., 0.26785955, 0.55852056,
#        0.50485003], dtype=float32), '116409198_0fe0c94f3b.jpg': array([0.24768041, 0.04594426, 0.55402386, ..., 0.6437851 , 0.4427799 ,
#        0.13747728], dtype=float32), '1184967930_9e29ce380d.jpg': array([0.43408826, 0.2652223 , 0.35177487, ..., 0.05068331, 0.68995976,
#        0.17085691], dtype=float32), '1095980313_3c94799968.jpg': array([0.28343427, 0.22547247, 0.65677905, ..., 0.38943607, 0.44618392,
#        1.022235  ], dtype=float32), '1189977786_4f5aaed773.jpg': array([0.10290186, 0.13473897, 0.31117505, ..., 0.5606408 , 0.12345909,
#        0.6767342 ], dtype=float32), '1206506157_c7956accd5.jpg': array([0.16947101, 0.11873985, 0.01645662, ..., 0.17832477, 0.65710926,
#        0.23293854], dtype=float32), '1187593464_ce862352c6.jpg': array([0.24126935, 0.59437686, 0.1839128 , ..., 0.7539689 , 0.5306917 ,
#        0.35388613], dtype=float32), '121800200_bef08fae5f.jpg': array([0.02621903, 0.20851901, 0.02924935, ..., 0.0022525 , 0.00187917,
#        1.0764687 ], dtype=float32), '1141739219_2c47195e4c.jpg': array([0.6032623 , 0.24132243, 1.1506827 , ..., 0.45451418, 0.21857055,
#        0.2351969 ], dtype=float32), '111537217_082a4ba060.jpg': array([0.00606063, 0.10341413, 0.25016633, ..., 0.5395024 , 0.62306005,
#        1.5348253 ], dtype=float32), '1075881101_d55c46bece.jpg': array([0.7901137 , 0.75857896, 0.54157466, ..., 0.5782901 , 0.72118324,
#        0.8368962 ], dtype=float32), '1144288288_e5c9558b6a.jpg': array([0.16554606, 0.45830244, 0.90561414, ..., 0.8691476 , 0.03642843,
#        0.04183026], dtype=float32), '1235681222_819231767a.jpg': array([0.5507652 , 0.30184418, 0.74928486, ..., 0.15176684, 0.76719224,
#        0.11590178], dtype=float32), '1094462889_f9966dafa6.jpg': array([0.31549785, 0.24316074, 0.3043999 , ..., 0.7859128 , 0.7476752 ,
#        0.49403247], dtype=float32), '1110208841_5bb6806afe.jpg': array([0.34649295, 0.72154725, 0.3379435 , ..., 0.321335  , 0.400267  ,
#        0.09009611], dtype=float32), '1042020065_fb3d3ba5ba.jpg': array([0.3414014 , 0.03150219, 0.3436823 , ..., 0.8095533 , 0.4988854 ,
#        0.716855  ], dtype=float32), '1132772170_600610c5df.jpg': array([0.25693393, 0.41808704, 0.15671507, ..., 0.13413396, 0.16069935,
#        0.32898968], dtype=float32), '1131804997_177c3c0640.jpg': array([0.4041197 , 0.24350193, 0.32843044, ..., 0.02601911, 0.93477166,
#        0.02783824], dtype=float32), '1130401779_8c30182e3e.jpg': array([0.24192777, 0.06365789, 0.34223557, ..., 0.8596777 , 1.30306   ,
#        0.45222223], dtype=float32), '1213336750_2269b51397.jpg': array([0.65602595, 0.38630164, 0.86120945, ..., 0.39820474, 0.5728743 ,
#        0.35778263], dtype=float32), '1057251835_6ded4ada9c.jpg': array([0.08511338, 0.29740918, 0.36536533, ..., 0.05078477, 1.2214794 ,
#        0.2505678 ], dtype=float32), '1067180831_a59dc64344.jpg': array([0.29708272, 0.6109745 , 0.0351277 , ..., 0.        , 0.345917  ,
#        0.3992188 ], dtype=float32), '1222322358_225067636e.jpg': array([0.0931076 , 0.22062439, 0.31444794, ..., 0.8315034 , 0.09520481,
#        0.00571394], dtype=float32), '1207159468_425b902bfb.jpg': array([0.31568426, 0.41480368, 0.34841794, ..., 0.1924595 , 1.0782739 ,
#        0.40791565], dtype=float32), '1169307342_e7a4685a5c.jpg': array([0.23271297, 0.13134427, 0.05863735, ..., 0.05594331, 0.41746396,
#        0.5304588 ], dtype=float32)}

# %% [markdown]
# **Tokenizing the vocabulary**

# %%
# list of all training captions 
all_train_captions = [] 
for key, val in train_descriptions.items(): 
    for caption in val: 
        all_train_captions.append(caption) 
  
# consider only words which occur atleast 10 times 
vocabulary = vocab 
threshold = 10
word_counts = {} 
for cap in all_train_captions: 
    for word in cap.split(' '): 
        word_counts[word] = word_counts.get(word, 0) + 1
  
vocab = [word for word in word_counts if word_counts[word] >= threshold] 
  
# word mapping to integers 
ixtoword = {} 
wordtoix = {} 
  
ix = 1
for word in vocab: 
    wordtoix[word] = ix 
    ixtoword[ix] = word 
    ix += 1
      
# find the maximum length of a description in a dataset 
max_length = max(len(des.split()) for des in all_train_captions) 
print(ixtoword)
print(wordtoix)
print(max_length)
# Out:
# {1: 'startofline', 2: 'child', 3: 'in', 4: 'pink', 5: 'dress', 6: 'is', 7: 'climbing', 8: 'up', 9: 'set', 10: 'of', 11: 'stairs', 12: 'an', 13: 'way', 14: 'endofline', 15: 'girl', 16: 'going', 17: 'into', 18: 'wooden', 19: 'building', 20: 'little', 21: 'the', 22: 'to', 23: 'her', 24: 'black', 25: 'dog', 26: 'and', 27: 'spotted', 28: 'are', 29: 'fighting', 30: 'tricolored', 31: 'playing', 32: 'with', 33: 'each', 34: 'other', 35: 'on', 36: 'road', 37: 'white', 38: 'brown', 39: 'spots', 40: 'staring', 41: 'at', 42: 'street', 43: 'two', 44: 'dogs', 45: 'different', 46: 'looking', 47: 'pavement', 48: 'moving', 49: 'toward', 50: 'covered', 51: 'paint', 52: 'sits', 53: 'front', 54: 'painted', 55: 'rainbow', 56: 'hands', 57: 'bowl', 58: 'sitting', 59: 'large', 60: 'small', 61: 'grass', 62: 'plays', 63: 'it', 64: 'there', 65: 'pigtails', 66: 'painting', 67: 'young', 68: 'outside', 69: 'man', 70: 'lays', 71: 'bench', 72: 'while', 73: 'his', 74: 'by', 75: 'him', 76: 'which', 77: 'also', 78: 'tied', 79: 'sleeping', 80: 'next', 81: 'shirtless', 82: 'lies', 83: 'park', 84: 'laying', 85: 'holding', 86: 'leash', 87: 'ground', 88: 'orange', 89: 'hat', 90: 'something', 91: 'wears', 92: 'glasses', 93: 'wearing', 94: 'beer', 95: 'can', 96: 'ears', 97: 'rope', 98: 'net', 99: 'red', 100: 'climbs', 101: 'bridge', 102: 'onto', 103: 'ropes', 104: 'playground', 105: 'running', 106: 'grassy', 107: 'garden', 108: 'surrounded', 109: 'fence', 110: 'through', 111: 'terrier', 112: 'green', 113: 'runs', 114: 'near', 115: 'shakes', 116: 'its', 117: 'head', 118: 'shore', 119: 'ball', 120: 'edge', 121: 'beach', 122: 'feet', 123: 'stands', 124: 'shaking', 125: 'off', 126: 'water', 127: 'standing', 128: 'turned', 129: 'one', 130: 'side', 131: 'boy', 132: 'smiles', 133: 'wall', 134: 'city', 135: 'overalls', 136: 'working', 137: 'stone', 138: 'walking', 139: 'paved', 140: 'metal', 141: 'pole', 142: 'behind', 143: 'smiling', 144: 'shirt', 145: 'blue', 146: 'jeans', 147: 'rock', 148: 'leaps', 149: 'over', 150: 'log', 151: 'grey', 152: 'leaping', 153: 'fallen', 154: 'tree', 155: 'collar', 156: 'jumping', 157: 'jumped', 158: 'stump', 159: 'snow', 160: 'field', 161: 'surface', 162: 'pictures', 163: 'skier', 164: 'skis', 165: 'past', 166: 'another', 167: 'person', 168: 'looks', 169: 'trees', 170: 'for', 171: 'cliff', 172: 'group', 173: 'people', 174: 'seven', 175: 'climbers', 176: 'face', 177: 'whilst', 178: 'several', 179: 'row', 180: 'watches', 181: 'holds', 182: 'line', 183: 'chases', 184: 'from', 185: 'sprinkler', 186: 'lawn', 187: 'hose', 188: 'away', 189: 'prepares', 190: 'catch', 191: 'thrown', 192: 'object', 193: 'nearby', 194: 'cars', 195: 'about', 196: 'yellow', 197: 'mouth', 198: 'toy', 199: 'ready', 200: 'flying', 201: 'air', 202: 'after', 203: 'get', 204: 'jumps', 205: 'towards', 206: 'trying', 207: 'midair', 208: 'couple', 209: 'infant', 210: 'being', 211: 'held', 212: 'male', 213: 'pond', 214: 'stroller', 215: 'sit', 216: 'baby', 217: 'their', 218: 'under', 219: 'facing', 220: 'lake', 221: 'woman', 222: 'along', 223: 'body', 224: 'outdoors', 225: 'surf', 226: 'lab', 227: 'splashes', 228: 'this', 229: 'splashing', 230: 'hole', 231: 'ice', 232: 'frozen', 233: 'men', 234: 'fishing', 235: 'play', 236: 'making', 237: 'turn', 238: 'sand', 239: 'together', 240: 'tan', 241: 'sandy', 242: 'uses', 243: 'climber', 244: 'jacket', 245: 'pants', 246: 'scaling', 247: 'waterfall', 248: 'carries', 249: 'as', 250: 'he', 251: 'walks', 252: 'carrying', 253: 'has', 254: 'item', 255: 'wet', 256: 'kayak', 257: 'life', 258: 'jackets', 259: 'rowing', 260: 'canoe', 261: 'waters', 262: 'ride', 263: 'courtyard', 264: 'catching', 265: 'chocolate', 266: 'driveway', 267: 'art', 268: 'structure', 269: 'glass', 270: 'reads', 271: 'newspaper', 272: 'sculpture', 273: 'office', 274: 'statue', 275: 'backpack', 276: 'buildings', 277: 'reading', 278: 'tent', 279: 'setting', 280: 'snowy', 281: 'very', 282: 'tall', 283: 'distance', 284: 'camera', 285: 'mountainside', 286: 'out', 287: 'view', 288:  ...
# {'startofline': 1, 'child': 2, 'in': 3, 'pink': 4, 'dress': 5, 'is': 6, 'climbing': 7, 'up': 8, 'set': 9, 'of': 10, 'stairs': 11, 'an': 12, 'way': 13, 'endofline': 14, 'girl': 15, 'going': 16, 'into': 17, 'wooden': 18, 'building': 19, 'little': 20, 'the': 21, 'to': 22, 'her': 23, 'black': 24, 'dog': 25, 'and': 26, 'spotted': 27, 'are': 28, 'fighting': 29, 'tricolored': 30, 'playing': 31, 'with': 32, 'each': 33, 'other': 34, 'on': 35, 'road': 36, 'white': 37, 'brown': 38, 'spots': 39, 'staring': 40, 'at': 41, 'street': 42, 'two': 43, 'dogs': 44, 'different': 45, 'looking': 46, 'pavement': 47, 'moving': 48, 'toward': 49, 'covered': 50, 'paint': 51, 'sits': 52, 'front': 53, 'painted': 54, 'rainbow': 55, 'hands': 56, 'bowl': 57, 'sitting': 58, 'large': 59, 'small': 60, 'grass': 61, 'plays': 62, 'it': 63, 'there': 64, 'pigtails': 65, 'painting': 66, 'young': 67, 'outside': 68, 'man': 69, 'lays': 70, 'bench': 71, 'while': 72, 'his': 73, 'by': 74, 'him': 75, 'which': 76, 'also': 77, 'tied': 78, 'sleeping': 79, 'next': 80, 'shirtless': 81, 'lies': 82, 'park': 83, 'laying': 84, 'holding': 85, 'leash': 86, 'ground': 87, 'orange': 88, 'hat': 89, 'something': 90, 'wears': 91, 'glasses': 92, 'wearing': 93, 'beer': 94, 'can': 95, 'ears': 96, 'rope': 97, 'net': 98, 'red': 99, 'climbs': 100, 'bridge': 101, 'onto': 102, 'ropes': 103, 'playground': 104, 'running': 105, 'grassy': 106, 'garden': 107, 'surrounded': 108, 'fence': 109, 'through': 110, 'terrier': 111, 'green': 112, 'runs': 113, 'near': 114, 'shakes': 115, 'its': 116, 'head': 117, 'shore': 118, 'ball': 119, 'edge': 120, 'beach': 121, 'feet': 122, 'stands': 123, 'shaking': 124, 'off': 125, 'water': 126, 'standing': 127, 'turned': 128, 'one': 129, 'side': 130, 'boy': 131, 'smiles': 132, 'wall': 133, 'city': 134, 'overalls': 135, 'working': 136, 'stone': 137, 'walking': 138, 'paved': 139, 'metal': 140, 'pole': 141, 'behind': 142, 'smiling': 143, 'shirt': 144, 'blue': 145, 'jeans': 146, 'rock': 147, 'leaps': 148, 'over': 149, 'log': 150, 'grey': 151, 'leaping': 152, 'fallen': 153, 'tree': 154, 'collar': 155, 'jumping': 156, 'jumped': 157, 'stump': 158, 'snow': 159, 'field': 160, 'surface': 161, 'pictures': 162, 'skier': 163, 'skis': 164, 'past': 165, 'another': 166, 'person': 167, 'looks': 168, 'trees': 169, 'for': 170, 'cliff': 171, 'group': 172, 'people': 173, 'seven': 174, 'climbers': 175, 'face': 176, 'whilst': 177, 'several': 178, 'row': 179, 'watches': 180, 'holds': 181, 'line': 182, 'chases': 183, 'from': 184, 'sprinkler': 185, 'lawn': 186, 'hose': 187, 'away': 188, 'prepares': 189, 'catch': 190, 'thrown': 191, 'object': 192, 'nearby': 193, 'cars': 194, 'about': 195, 'yellow': 196, 'mouth': 197, 'toy': 198, 'ready': 199, 'flying': 200, 'air': 201, 'after': 202, 'get': 203, 'jumps': 204, 'towards': 205, 'trying': 206, 'midair': 207, 'couple': 208, 'infant': 209, 'being': 210, 'held': 211, 'male': 212, 'pond': 213, 'stroller': 214, 'sit': 215, 'baby': 216, 'their': 217, 'under': 218, 'facing': 219, 'lake': 220, 'woman': 221, 'along': 222, 'body': 223, 'outdoors': 224, 'surf': 225, 'lab': 226, 'splashes': 227, 'this': 228, 'splashing': 229, 'hole': 230, 'ice': 231, 'frozen': 232, 'men': 233, 'fishing': 234, 'play': 235, 'making': 236, 'turn': 237, 'sand': 238, 'together': 239, 'tan': 240, 'sandy': 241, 'uses': 242, 'climber': 243, 'jacket': 244, 'pants': 245, 'scaling': 246, 'waterfall': 247, 'carries': 248, 'as': 249, 'he': 250, 'walks': 251, 'carrying': 252, 'has': 253, 'item': 254, 'wet': 255, 'kayak': 256, 'life': 257, 'jackets': 258, 'rowing': 259, 'canoe': 260, 'waters': 261, 'ride': 262, 'courtyard': 263, 'catching': 264, 'chocolate': 265, 'driveway': 266, 'art': 267, 'structure': 268, 'glass': 269, 'reads': 270, 'newspaper': 271, 'sculpture': 272, 'office': 273, 'statue': 274, 'backpack': 275, 'buildings': 276, 'reading': 277, 'tent': 278, 'setting': 279, 'snowy': 280, 'very': 281, 'tall': 282, 'distance': 283, 'camera': 284, 'mountainside': 285, 'out': 286, 'view': 287, 'thre ...
# 34

# %% [markdown]
# **Text vector embeddings using pre trained GloVe vectore representations**

# %%
vocab_size = len(vocab) + 1
X1, X2, y = list(), list(), list() 
for key, des_list in train_descriptions.items(): 
    pic = encoding_train[key + '.jpg'] 
    for cap in des_list: 
        seq = [wordtoix[word] for word in cap.split(' ') if word in wordtoix] 
        for i in range(1, len(seq)): 
            in_seq, out_seq = seq[:i], seq[i] 
            #Padding to ensure all values are same size - https://stackoverflow.com/questions/42943291/what-does-keras-io-preprocessing-sequence-pad-sequences-do
            in_seq = pad_sequences([in_seq], maxlen = max_length)[0] 
            out_seq = to_categorical([out_seq], num_classes = vocab_size)[0] 
            # store 
            X1.append(pic) 
            X2.append(in_seq) 
            y.append(out_seq) 
  
X2 = np.array(X2) 
X1 = np.array(X1) 
y = np.array(y) 
  
# load glove vectors for embedding layer 
embeddings_index = {} 
golve_path ='/content/drive/MyDrive/glove.6B.200d.txt' #Trained on 2014 Wikipedia corpus
glove = open(golve_path, 'r', encoding = 'utf-8').read() 
for line in glove.split("\n"): 
    values = line.split(" ") 
    word = values[0] 
    indices = np.asarray(values[1: ], dtype = 'float32') 
    embeddings_index[word] = indices 
  
emb_dim = 200
#Relationship bw words in vector space
emb_matrix = np.zeros((vocab_size, emb_dim)) 
for word, i in wordtoix.items(): 
    emb_vec = embeddings_index.get(word) 
    if emb_vec is not None: 
        emb_matrix[i] = emb_vec 
print(emb_matrix.shape)
# Out:
# (1652, 200)

# %% [markdown]
# **Model**

# %%
# define the model - Encoder Decoder model
input1 = Input(shape = (2048, )) 
feature1 = Dropout(0.2)(input1) 
feature2 = Dense(256, activation = 'relu')(feature1) 
input2 = Input(shape = (max_length, )) 
sequence1 = Embedding(vocab_size, emb_dim, mask_zero = True)(input2) 
sequence2 = Dropout(0.2)(sequence1) 
sequence3 = LSTM(256)(sequence2) 
decoder1 = add([feature2, sequence3]) 
decoder2 = Dense(256, activation = 'relu')(decoder1) 
outputs = Dense(vocab_size, activation = 'softmax')(decoder2) 
model = Model(inputs = [input1, input2], outputs = outputs)
print(model.summary())
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 34)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2048)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 34, 200)      330400      input_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           input_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 34, 200)      0           embedding[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          524544      dropout[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 256)          467968      dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256)          0           dense[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       add[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1652)         424564      dense_1[0][0]
# ==================================================================================================
# Total params: 1,813,268
# Trainable params: 1,813,268
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# **Model Training**

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/drive/MyDrive/flickr8k/caption.ckpt',
                                                 save_weights_only=True,
                                                 verbose=1)

#Not to train the embedding layer
model.layers[2].set_weights([emb_matrix]) 
model.layers[2].trainable = False
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam') 
model.fit([X1, X2], y, epochs = 100, batch_size = 256, callbacks=[cp_callback]) 
model.save('/content/drive/MyDrive/flickr8k/caption_model.h5')
# Out:
# Epoch 1/100
# 1142/1142 [==============================] - ETA: 0s - loss: 3.9021
# Epoch 00001: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 3.9021
# Epoch 2/100
# 1142/1142 [==============================] - ETA: 0s - loss: 3.1632
# Epoch 00002: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 81ms/step - loss: 3.1632
# Epoch 3/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.9301
# Epoch 00003: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 2.9301
# Epoch 4/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.7751
# Epoch 00004: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 2.7751
# Epoch 5/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.6597
# Epoch 00005: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 82ms/step - loss: 2.6597
# Epoch 6/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.5667
# Epoch 00006: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 2.5667
# Epoch 7/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.4908
# Epoch 00007: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 84ms/step - loss: 2.4908
# Epoch 8/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.4252
# Epoch 00008: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 82ms/step - loss: 2.4252
# Epoch 9/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.3641
# Epoch 00009: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 2.3641
# Epoch 10/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.3119
# Epoch 00010: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 2.3119
# Epoch 11/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.2648
# Epoch 00011: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 2.2648
# Epoch 12/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.2216
# Epoch 00012: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 2.2216
# Epoch 13/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.1844
# Epoch 00013: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 2.1844
# Epoch 14/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.1471
# Epoch 00014: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 90s 79ms/step - loss: 2.1471
# Epoch 15/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.1161
# Epoch 00015: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 79ms/step - loss: 2.1161
# Epoch 16/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.0865
# Epoch 00016: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 2.0865
# Epoch 17/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.0622
# Epoch 00017: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 2.0622
# Epoch 18/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.0382
# Epoch 00018: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 2.0382
# Epoch 19/100
# 1142/1142 [==============================] - ETA: 0s - loss: 2.0131
# Epoch 00019: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 83ms/step - loss: 2.0131
# Epoch 20/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.9936
# Epoch 00020: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.9936
# Epoch 21/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.9718
# Epoch 00021: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.9718
# Epoch 22/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.9533
# Epoch 00022: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.9533
# Epoch 23/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.9391
# Epoch 00023: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.9391
# Epoch 24/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.9254
# Epoch 00024: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.9254
# Epoch 25/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.9094
# Epoch 00025: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.9094
# Epoch 26/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8980
# Epoch 00026: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 82ms/step - loss: 1.8980
# Epoch 27/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8803
# Epoch 00027: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.8803
# Epoch 28/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8735
# Epoch 00028: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 82ms/step - loss: 1.8735
# Epoch 29/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8614
# Epoch 00029: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 83ms/step - loss: 1.8614
# Epoch 30/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8519
# Epoch 00030: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 81ms/step - loss: 1.8519
# Epoch 31/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8413
# Epoch 00031: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 82ms/step - loss: 1.8413
# Epoch 32/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8337
# Epoch 00032: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 81ms/step - loss: 1.8337
# Epoch 33/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8240
# Epoch 00033: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.8240
# Epoch 34/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8152
# Epoch 00034: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.8152
# Epoch 35/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.8058
# Epoch 00035: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.8058
# Epoch 36/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7987
# Epoch 00036: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.7987
# Epoch 37/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7939
# Epoch 00037: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 82ms/step - loss: 1.7939
# Epoch 38/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7851
# Epoch 00038: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.7851
# Epoch 39/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7778
# Epoch 00039: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.7778
# Epoch 40/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7738
# Epoch 00040: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.7738
# Epoch 41/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7671
# Epoch 00041: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.7671
# Epoch 42/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7634
# Epoch 00042: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.7634
# Epoch 43/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7541
# Epoch 00043: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.7541
# Epoch 44/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7532
# Epoch 00044: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 96s 84ms/step - loss: 1.7532
# Epoch 45/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7441
# Epoch 00045: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 98s 85ms/step - loss: 1.7441
# Epoch 46/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7446
# Epoch 00046: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 99s 87ms/step - loss: 1.7446
# Epoch 47/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7366
# Epoch 00047: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 101s 88ms/step - loss: 1.7366
# Epoch 48/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7361
# Epoch 00048: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 100s 88ms/step - loss: 1.7361
# Epoch 49/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7294
# Epoch 00049: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 99s 87ms/step - loss: 1.7294
# Epoch 50/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7238
# Epoch 00050: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 101s 89ms/step - loss: 1.7238
# Epoch 51/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7212
# Epoch 00051: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 103s 90ms/step - loss: 1.7212
# Epoch 52/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7172
# Epoch 00052: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 105s 92ms/step - loss: 1.7172
# Epoch 53/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7130
# Epoch 00053: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 105s 92ms/step - loss: 1.7130
# Epoch 54/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7087
# Epoch 00054: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 102s 90ms/step - loss: 1.7087
# Epoch 55/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7054
# Epoch 00055: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 103s 90ms/step - loss: 1.7054
# Epoch 56/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7050
# Epoch 00056: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 101s 89ms/step - loss: 1.7050
# Epoch 57/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.7026
# Epoch 00057: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 99s 87ms/step - loss: 1.7026
# Epoch 58/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6975
# Epoch 00058: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 102s 89ms/step - loss: 1.6975
# Epoch 59/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6931
# Epoch 00059: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 99s 87ms/step - loss: 1.6931
# Epoch 60/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6922
# Epoch 00060: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 100s 87ms/step - loss: 1.6922
# Epoch 61/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6913
# Epoch 00061: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.6913
# Epoch 62/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6856
# Epoch 00062: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 81ms/step - loss: 1.6856
# Epoch 63/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6854
# Epoch 00063: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 81ms/step - loss: 1.6854
# Epoch 64/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6816
# Epoch 00064: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.6816
# Epoch 65/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6778
# Epoch 00065: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.6778
# Epoch 66/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6725
# Epoch 00066: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 82ms/step - loss: 1.6725
# Epoch 67/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6745
# Epoch 00067: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6745
# Epoch 68/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6744
# Epoch 00068: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.6744
# Epoch 69/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6680
# Epoch 00069: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.6680
# Epoch 70/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6680
# Epoch 00070: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 81ms/step - loss: 1.6680
# Epoch 71/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6661
# Epoch 00071: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.6661
# Epoch 72/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6612
# Epoch 00072: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.6612
# Epoch 73/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6591
# Epoch 00073: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 83ms/step - loss: 1.6591
# Epoch 74/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6616
# Epoch 00074: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 95s 84ms/step - loss: 1.6616
# Epoch 75/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6578
# Epoch 00075: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 94s 82ms/step - loss: 1.6578
# Epoch 76/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6552
# Epoch 00076: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.6552
# Epoch 77/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6524
# Epoch 00077: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6524
# Epoch 78/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6562
# Epoch 00078: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6562
# Epoch 79/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6483
# Epoch 00079: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.6483
# Epoch 80/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6475
# Epoch 00080: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6475
# Epoch 81/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6455
# Epoch 00081: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.6455
# Epoch 82/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6433
# Epoch 00082: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 81ms/step - loss: 1.6433
# Epoch 83/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6427
# Epoch 00083: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.6427
# Epoch 84/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6407
# Epoch 00084: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.6407
# Epoch 85/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6392
# Epoch 00085: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.6392
# Epoch 86/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6391
# Epoch 00086: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.6391
# Epoch 87/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6367
# Epoch 00087: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6367
# Epoch 88/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6354
# Epoch 00088: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 90s 79ms/step - loss: 1.6354
# Epoch 89/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6345
# Epoch 00089: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6345
# Epoch 90/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6352
# Epoch 00090: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.6352
# Epoch 91/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6307
# Epoch 00091: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 82ms/step - loss: 1.6307
# Epoch 92/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6341
# Epoch 00092: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.6341
# Epoch 93/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6303
# Epoch 00093: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 90s 79ms/step - loss: 1.6303
# Epoch 94/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6267
# Epoch 00094: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6267
# Epoch 95/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6290
# Epoch 00095: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 80ms/step - loss: 1.6290
# Epoch 96/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6223
# Epoch 00096: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 91s 80ms/step - loss: 1.6223
# Epoch 97/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6260
# Epoch 00097: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6260
# Epoch 98/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6250
# Epoch 00098: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6250
# Epoch 99/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6220
# Epoch 00099: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 92s 81ms/step - loss: 1.6220
# Epoch 100/100
# 1142/1142 [==============================] - ETA: 0s - loss: 1.6213
# Epoch 00100: saving model to /content/drive/MyDrive/flickr8k/caption.ckpt
# 1142/1142 [==============================] - 93s 81ms/step - loss: 1.6213

# %%
from tensorflow import keras
model.load_weights('/content/drive/MyDrive/flickr8k/caption.ckpt')
#model = keras.models.load_model('/content/drive/MyDrive/flickr8k/caption_model.h5')

# %%
#Test data
import glob 
images = '/content/drive/MyDrive/Flickr_Data/Images/'
# Create a list of all image names in the directory 
img = glob.glob(images + '*.jpg')

test_path = '/content/drive/MyDrive/Flickr_Data/Flickr_TextData/Flickr_8k.testImages.txt'
test_images = open(test_path, 'r', encoding = 'utf-8').read().split("\n") 
test_img = []  # list of all images in training set 
for im in img: 
    #print(im[len(images):])
    if(im[len(images):] in test_images): 
        test_img.append(im)

# %% [markdown]
# **Inference**

# %%
from keras.preprocessing.image import load_img, img_to_array 
def predict_caption(pic): 
    start = 'startofline'
    for i in range(max_length): 
        seq = [wordtoix[word] for word in start.split() if word in wordtoix]    
        seq = pad_sequences([seq], maxlen = max_length) 
        yhat = model.predict([pic, seq], verbose = 0) 
        yhat = np.argmax(yhat) 
        word = ixtoword[yhat] 
        start += ' ' + word 
        if word == 'endofline': 
            break
    final = start.split() 
    final = final[1:-1] 
    final = ' '.join(final) 
    return final

def generate_feature(tst_img):
  base_model_1 = InceptionV3(weights = 'imagenet') 
  predict_model = Model(base_model_1.input, base_model_1.layers[-2].output) 
  img = load_img(tst_img, target_size = (299, 299)) 
  img = img_to_array(img)
  img_show = img/255
  plt.imshow(img_show)
  plt.show()
  img = img.reshape((1, img.shape[0], img.shape[1], img.shape[2]))
  img = preprocess_input(img)  
  feature = predict_model.predict(img, verbose=0)
  return feature

# %%
for i, tst_img in enumerate(test_img):
  feature = generate_feature(tst_img)
  final_caption = predict_caption(feature)
  print(final_caption)
  if i>10:
    break
# Out:
# woman in red shirt and khaki pants sits on rocks near large
# little boy is playing with green in the water
# boy in red and white swimming suit does face
# man and woman are standing in front of building that has been painted on the side of them
# man wearing red jacket is standing in crowd
# man in red jacket and leather jacket is taking photo of man in orange
# the boy is performing jump on the slide
# man in blue jacket is walking past snow
# white dog is running through the dirt
# dog is running through the grass
# man in black jacket is standing in front of crowd
# brown dog runs through field
